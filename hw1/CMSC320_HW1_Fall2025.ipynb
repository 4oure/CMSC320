# %% [markdown]
# # **HOMEWORK 1 (110 points + 1) : CAUTION! CONTENTS ARE HOT** 🌋
# ## **DUE: *SEPTEMBER 18, 2025 @ 11:59 PM***
# ## **24-HR LATE DUE DATE WITH A 15% PENALTY: *SEPTEMBER 19, 2025 @ 11:59 PM***
#
# The [NCEI/WDS Global Significant Volcanic Eruptions Database](https://www.ncei.noaa.gov/access/metadata/landing-page/bin/iso?id=gov.noaa.ngdc.mgg.hazards:G10147) is a very comprehensive collection of +600 volcanic eruptions dating from 4360 BC to the present. Due to the nature of this assignment, we will be dealing with relatively newer volcanoes (in which some are still obviously still older than anyone on Earth currently). Each eruption in the database is classified as significant if it meets one or more criteria, such as causing fatalities, incurring **damage on property** (**+$1 million**), reaching a **Volcanic Explosivity Index (VEI)** of **6 or higher**, generating a tsunami, or being linked to a significant earthquake. The VEI is a scale that measures the explosiveness of volcanic eruptions, providing insight into the magnitude and potential consequences of the eruptions. The database includes detailed information on the location, type of volcano, last known eruption, VEI, casualties, property damage, and much more.
# ![volcano](https://wikitravel.org/upload/shared//9/99/Volcano_de_Fuego_Banner.jpg)
# **We are going to dive straight into these volcanoes (well... their dataset), to swim our way into Pandas proficiency!**
#
# You will find the [Pandas Documentation](https://pandas.pydata.org/docs/user_guide/index.html) helpful. There are also some helpful links to guide you along the way! Don't get burned 🔥

# %% [markdown]
# # **For this assignment, we are including a special bonus question to help everyone get familiar with the proper assignment submission routine. We strongly encourage you to complete Bonus Question 1, learn the process, and follow this practice for all future assignments.**
#
# # **For this assignment only, you will not lose points if you skip the bonus question. However, starting from Homework 2, submitting both the Jupyter Notebook file and the PDF will be required in order to receive full credit.**
#
# ### **DO NOT REMOVE ANY PART OF ANY OF THE QUESTIONS OR YOU LOSE CREDIT**
# ### *No Hardcoding either*  😋❤️‍🔥
# ### **REMEMBER TO SHOW OUTPUT**

# %% [markdown]
# ### **Part 1: Maintenance 🤩 (25 POINTS TOTAL)**
# First, we're going to familiarize ourselves with the process. As in most languages, Python looks best when its modules are imported first before any other code is written ✨

# %%
# Make sure these code blocks run properly and that you have properly installed the appropriate modules required.
import pandas as pd
import requests
# import other libraries here

# Don't Remove this
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# As you may have noticed, there's another library aside from Pandas called "[requests](https://requests.readthedocs.io/en/latest/)." **The requests library allows you to send HTTP requests to a server, retrieve the content, and process it at ease.** It's very beginner friendly for those attempting to get into webscraping (super important for collecting and creating datasets). We also recommend looking into [BeautifulSoup](https://beautiful-soup-4.readthedocs.io/en/latest/) (yeah, soup LOL), another wonderful library that can be paired with the requests library for webscraping.
#
# As shown below, sometimes specific websites require specific headers in order to process a request to access the data.
#
# To check if a request was processed successfully, use the [status_code](https://requests.readthedocs.io/en/latest/api/) function to see if the process returned 200.

# %%
# API URL and headers in case request gets denied.
api_url = "https://www.ngdc.noaa.gov/hazel/hazard-service/api/v1/volcanoes"

headers = {
    'accept': '*/*'
}

# %% [markdown]
# #### **TASK 1.0: Cute Webscraping (5 points)**
# To make our cute webscraper we need to **create a GET request** using the relevant information given above.
#
# This particular dataset NOAA returns data from the API as ***json*** when a user makes a request. The json data has a particular format, so we will extract our needed information only from the field called **items** to make a dataframe.
#
# **After properly scraping the data, name this dataframe** ***df***
#
# **Save this dataframe into a CSV file named 'volcanoes.csv'**
#
# **You won't need to run this more than once**

# %%
response = requests.get(api_url, headers=headers)
response.raise_for_status

data = response.json()

items = data["items"]
df = pd.DataFrame(items)
df.to_csv("volcanoes.csv", index = False)

# %% [markdown]
# #### **TASK 1.1: 1 Liner Thingz (3 points)**
#
# We need to get an idea of what this dataset is going to look. In order to do that, let's take a look at some of the most [basic things](https://dataanalytics.buffalostate.edu/pandas-cheat-sheet) our dataframe has.
#
# **Read the directions carefully and code your answer with only one line of code.**
#
# ***CAN'T USE LOOPS. DO NOT DISPLAY THE DATAFRAME, JUST YOUR CODE OUTPUT HERE.***

# %% [markdown]
# **1.1.1:** In one line of code and **using only one single method call**, output the **summary statistics** (count, mean, std, min, max, quartiles) of all numerical features in the dataframe.
#
# *Hint: Look for a method that gives a descriptive overview of numerical columns.*

# %%
df.describe()
# Out:
#                id         year       month         day  tsunamiEventId  \
# count  200.000000   200.000000  177.000000  155.000000       37.000000
# mean   375.635000  1809.800000    6.293785   15.825806     1818.648649
# std    306.114755   248.034282    3.469611    9.185073     1742.563313
# min      1.000000  -141.000000    1.000000    1.000000       61.000000
# 25%     78.500000  1774.500000    3.000000    8.000000      613.000000
# 50%    348.000000  1880.500000    7.000000   15.000000     1181.000000
# 75%    664.250000  1950.000000    9.000000   24.000000     1977.000000
# max    994.000000  1996.000000   12.000000   31.000000     5863.000000
#
#        earthquakeEventId  volcanoLocationId  volcanoLocationNewNum  \
# count          17.000000         200.000000             200.000000
# mean         3632.117647       57207.110000          258519.715000
# std          3015.859162       24461.022227           20706.407256
# min           421.000000       10101.000000          211010.000000
# 25%          1328.000000       60325.000000          263250.000000
# 50%          2179.000000       60403.000000          264015.000000
# 75%          6195.000000       60807.000000          268070.000000
# max         10519.000000      201141.000000          282110.000000
#
#          latitude   longitude    elevation   deathsTotal  \
# count  200.000000  200.000000   200.000000    128.000000
# mean     5.852440  103.641705  1835.110000   1028.007812
# std     18.170994   48.350940  1032.617325   5692.045543
# min    -38.157000 -175.630000    -5.000000      1.000000
# 25%     -7.935000  111.847000  1117.000000      3.000000
# 50%      0.320000  121.299500  1714.000000     18.000000
# 75%     14.011000  127.332000  2805.000000    104.250000
# max     40.827000  177.180000  3657.000000  60000.000000
#
#        deathsAmountOrderTotal  damageAmountOrderTotal         vei  \
# count              180.000000               59.000000  192.000000
# mean                 1.677778                2.084746    2.692708
# std                  1.039207                0.952096    0.956843
# min                  1.000000                1.000000    0.000000
# 25%                  1.000000                1.000000    2.000000
# 50%                  1.000000                2.000000    3.000000
# 75%                  2.000000                3.000000    3.000000
# max                  4.000000                4.000000    7.000000
#
#        deathsAmountOrder  damageAmountOrder  housesDestroyedAmountOrderTotal  \
# count         169.000000          51.000000                        52.000000
# mean            1.609467           1.823529                         2.403846
# std             0.994703           0.931791                         0.995275
# min             1.000000           1.000000                         1.000000
# 25%             1.000000           1.000000                         1.750000
# 50%             1.000000           2.000000                         3.000000
# 75%             2.000000           3.000000                         3.000000
# max             4.000000           4.000000                         4.000000
#
#              deaths     injuries  injuriesAmountOrder  injuriesTotal  \
# count    118.000000    30.000000            39.000000      33.000000
# mean     429.483051    90.400000             1.589744     113.060606
# std     1513.433735   210.136507             0.849704     227.506310
# min        1.000000     1.000000             1.000000       1.000000
# 25%        3.000000     5.250000             1.000000       6.000000
# 50%       13.500000    21.500000             1.000000      26.000000
# 75%       78.500000    54.500000             2.000000      86.000000
# max    11000.000000  1000.000000             4.000000    1000.000000
#
#        injuriesAmountOrderTotal  housesDestroyedAmountOrder  housesDestroyed  \
# count                 41.000000                   42.000000        13.000000
# mean                   1.682927                    2.309524      1102.000000
# std                    0.878608                    1.047368      2451.426863
# min                    1.000000                    1.000000        10.000000
# 25%                    1.000000                    1.000000        50.000000
# 50%                    1.000000                    2.500000       144.000000
# 75%                    2.000000                    3.000000       800.000000
# max                    4.000000                    4.000000      9000.000000
#
#        housesDestroyedTotal  missingAmountOrder  missingAmountOrderTotal  \
# count             16.000000                 3.0                      3.0
# mean            1326.312500                 2.0                      2.0
# std             2568.800543                 1.0                      1.0
# min               10.000000                 1.0                      1.0
# 25%               68.750000                 1.5                      1.5
# 50%              215.500000                 2.0                      2.0
# 75%              877.250000                 2.5                      2.5
# max             9000.000000                 3.0                      3.0
#
#        missing  missingTotal  damageMillionsDollars  \
# count      1.0           1.0                   1.00
# mean      78.0          78.0                   0.04
# std        NaN           NaN                    NaN
# min       78.0          78.0                   0.04
# 25%       78.0          78.0                   0.04
# 50%       78.0          78.0                   0.04
# 75%       78.0          78.0                   0.04
# max       78.0          78.0                   0.04
#
#        damageMillionsDollarsTotal
# count                         1.0
# mean                         19.0
# std                           NaN
# min                          19.0
# 25%                          19.0
# 50%                          19.0
# 75%                          19.0
# max                          19.0

# %% [markdown]
# **1.1.2:** In one line of code and **using only one single method call**, print the **summary information** of the dataframe, including index dtype, column names, non-null counts, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               200 non-null    int64
#  1   year                             200 non-null    int64
#  2   month                            177 non-null    float64
#  3   day                              155 non-null    float64
#  4   tsunamiEventId                   37 non-null     float64
#  5   earthquakeEventId                17 non-null     float64
#  6   volcanoLocationId                200 non-null    int64
#  7   volcanoLocationNewNum            200 non-null    int64
#  8   volcanoLocationNum               200 non-null    object
#  9   name                             200 non-null    object
#  10  location                         200 non-null    object
#  11  country                          200 non-null    object
#  12  latitude                         200 non-null    float64
#  13  longitude                        200 non-null    float64
#  14  elevation                        200 non-null    int64
#  15  morphology                       200 non-null    object
#  16  agent                            128 non-null    object
#  17  deathsTotal                      128 non-null    float64
#  18  deathsAmountOrderTotal           180 non-null    float64
#  19  damageAmountOrderTotal           59 non-null     float64
#  20  significant                      200 non-null    bool
#  21  publish                          200 non-null    bool
#  22  eruption                         200 non-null    bool
#  23  status                           200 non-null    object
#  24  timeErupt                        200 non-null    object
#  25  vei                              192 non-null    float64
#  26  deathsAmountOrder                169 non-null    float64
#  27  damageAmountOrder                51 non-null     float64
#  28  housesDestroyedAmountOrderTotal  52 non-null     float64
#  29  deaths                           118 non-null    float64
#  30  injuries                         30 non-null     float64
#  31  injuriesAmountOrder              39 non-null     float64
#  32  injuriesTotal                    33 non-null     float64
#  33  injuriesAmountOrderTotal         41 non-null     float64
#  34  housesDestroyedAmountOrder       42 non-null     float64
#  35  housesDestroyed                  13 non-null     float64
#  36  housesDestroyedTotal             16 non-null     float64
#  37  missingAmountOrder               3 non-null      float64
#  38  missingAmountOrderTotal          3 non-null      float64
#  39  missing                          1 non-null      float64
#  40  missingTotal                     1 non-null      float64
#  41  damageMillionsDollars            1 non-null      float64
#  42  damageMillionsDollarsTotal       1 non-null      float64
# dtypes: bool(3), float64(27), int64(5), object(8)
# memory usage: 63.2+ KB

# %% [markdown]
# We won't be using some of the data because there is a lot of missing data.
#
# **1.1.3:** *In one line of code, create a **new dataframe** called **new_df** that **discards** all the features of the **old** dataframe **except for the following**:*
#
# `id,	year, month, day,	tsunamiEventId, earthquakeEventId, volcanoLocationId, volcanoLocationNewNum, name, country, elevation, morphology, deathsTotal, vei, deaths`
#
# *Hint: Don't use any drop function*

# %%
new_df = df[["id",	"year","month", "day","tsunamiEventId", "earthquakeEventId", "volcanoLocationId", "volcanoLocationNewNum", "name", "country", "elevation", "morphology", "deathsTotal", "vei", "deaths"]]

# %% [markdown]
# #### **TASK 1.2: 1 Liner Shenaniganz (7 points)**
#
# We're going to tidy up the **new dataframe** a little more with some more advanced 1 liner code.
#
# **Read the directions carefully and code your answer with only one line of code.**
#
# **For this section, keep the method of display that is already in the box. Write your code as indicated.**
#
# ***YOU CAN'T USE ONE LINE LOOPS OR ANY KIND OF LOOP.***

# %% [markdown]
# **1.2.1:** *In one line of code, **drop any row** that contains **NaN** in **any one** of the columns indicating a measure of **time**.*

# %%
new_df.dropna(subset=["year", "month", "day"])
# Out:
#       id  year  month   day  tsunamiEventId  earthquakeEventId  \
# 0      1  1169    2.0   4.0          2852.0              421.0
# 1      2  1329    7.0  15.0             NaN                NaN
# 3      4  1888    3.0  13.0          1175.0                NaN
# 5      6  1832   11.0   1.0             NaN                NaN
# 6      7  1977    1.0  10.0             NaN                NaN
# 8      9  1779    8.0   8.0             NaN                NaN
# 10    11  1907    8.0   4.0             NaN                NaN
# 11    12  1905    3.0  10.0             NaN                NaN
# 12    13  1986    7.0  24.0             NaN                NaN
# 13    14  1536    3.0  26.0             NaN                NaN
# 14    15  1904    2.0  25.0             NaN                NaN
# 15    16  1878    2.0   4.0          1095.0             6195.0
# 16    17  1737    5.0  20.0             NaN                NaN
# 17    18  1917    4.0   1.0             NaN                NaN
# 19    20  1979    3.0   8.0             NaN                NaN
# 20    21  1970    3.0   2.0             NaN                NaN
# 22    23  1682    8.0  12.0             NaN                NaN
# 23    24  1805    8.0  11.0             NaN                NaN
# 24    25  1919    5.0  22.0          1476.0                NaN
# 25    26  1930    9.0  11.0          4218.0                NaN
# 26    27  1903    8.0  30.0             NaN                NaN
# 27    28  1928   11.0   8.0             NaN                NaN
# 28    29  1872    4.0  24.0             NaN                NaN
# 29    30  1979    9.0  12.0             NaN                NaN
# 30    31  1987    4.0  17.0             NaN                NaN
# 31    32  1914    9.0  10.0             NaN                NaN
# 32    33  1886    8.0  31.0             NaN                NaN
# 33    34  1912   12.0   3.0             NaN                NaN
# 34    35  1895    6.0  17.0             NaN                NaN
# 35    36  1538    9.0  29.0             NaN                NaN
# 36    37  1853    6.0  24.0             NaN                NaN
# 37    38  1954    8.0   3.0             NaN                NaN
# 38    39  1944    3.0  27.0             NaN                NaN
# 39    40  1984    8.0  15.0          5807.0                NaN
# 41    42  1926    1.0  23.0             NaN                NaN
# 42    43  1631    2.0  14.0             NaN              920.0
# 43    44  1843   11.0  25.0             NaN                NaN
# 44    45  1944   12.0   4.0             NaN                NaN
# 45    49  1979    2.0  20.0             NaN                NaN
# 47    64  1672    8.0   4.0             NaN                NaN
# 48    69  1822   12.0  27.0             NaN                NaN
# 49    71  1832   12.0  25.0             NaN                NaN
# 50    81  1872    4.0  15.0             NaN                NaN
# 51    82  1872   11.0   3.0             NaN                NaN
# 53    92  1920    7.0  25.0             NaN                NaN
# 54    94  1930   12.0  18.0             NaN                NaN
# 55   100  1954    1.0  18.0             NaN                NaN
# 56   104  1961    5.0   8.0             NaN                NaN
# 57   105  1969    1.0   7.0             NaN                NaN
# 58   111  1986   12.0  31.0             NaN                NaN
# 59   112  1994   11.0  22.0             NaN                NaN
# 65   128  1716    7.0  20.0             NaN                NaN
# 66   132  1826   10.0  13.0             NaN                NaN
# 67   133  1848    5.0  16.0             NaN                NaN
# 68   135  1864    1.0   4.0             NaN                NaN
# 69   136  1875    1.0  29.0             NaN                NaN
# 70   137  1901    5.0  22.0             NaN                NaN
# 71   138  1919    5.0  19.0             NaN                NaN
# 72   140  1951    8.0  31.0             NaN                NaN
# 73   141  1966    4.0  26.0             NaN                NaN
# 74   144  1990    2.0  10.0             NaN                NaN
# 76   167  1885    4.0  18.0             NaN                NaN
# 77   176  1895    5.0  22.0             NaN                NaN
# 78   191  1909    8.0  29.0             NaN                NaN
# 79   193  1911   11.0   8.0             NaN                NaN
# 80   195  1913    6.0  23.0             NaN                NaN
# 81   196  1941    9.0  21.0             NaN                NaN
# 83   199  1946   10.0  29.0             NaN                NaN
# 84   200  1950    8.0  28.0             NaN                NaN
# 85   201  1963    5.0   5.0             NaN                NaN
# 86   202  1967    8.0  31.0             NaN                NaN
# 87   203  1985    5.0  10.0             NaN                NaN
# 88   204  1978    9.0  19.0             NaN                NaN
# 89   205  1976    8.0  31.0             NaN                NaN
# 90   206  1981    3.0  29.0             NaN                NaN
# 98   333  1817    1.0  24.0             NaN                NaN
# 99   345  1963    9.0   5.0             NaN                NaN
# 100  351  1963    3.0  18.0          1942.0                NaN
# 101  353  1963    5.0  16.0             NaN             4292.0
# 102  367  1815    4.0  10.0           613.0                NaN
# 103  389  1969    1.0  28.0             NaN                NaN
# 104  394  1928    8.0   4.0          1607.0                NaN
# 105  395  1964    1.0   1.0             NaN                NaN
# 107  398  1981    9.0   5.0             NaN                NaN
# 108  410  1869    7.0   7.0             NaN                NaN
# 109  411  1907    9.0  28.0             NaN                NaN
# 111  441  1948    4.0   7.0             NaN                NaN
# 113  447  1983    8.0  17.0          4702.0                NaN
# 115  457  1659   11.0  11.0           285.0                NaN
# 117  466  1692    6.0   4.0             NaN                NaN
# 120  477  1694   11.0  20.0             NaN                NaN
# 121  482  1820    6.0  11.0             NaN                NaN
# 122  486  1988    5.0   9.0             NaN                NaN
# 123  488  1983    7.0  23.0             NaN                NaN
# 124  489  1845    2.0   8.0           741.0             1865.0
# 125  525  1958    7.0  12.0             NaN                NaN
# 127  533  1871    3.0   3.0          1022.0                NaN
# 128  552  1940    6.0  20.0             NaN                NaN
# 129  561  1974    2.0  11.0             NaN                NaN
# 130  562  1976    9.0  15.0             NaN                NaN
# 131  569  1889    9.0   6.0          1181.0             6309.0
# 132  578  1711   12.0  11.0             NaN                NaN
# 133  580  1812    8.0   6.0             NaN                NaN
# 134  581  1856    3.0   2.0           859.0             1995.0
# 135  584  1892    6.0   7.0          1197.0                NaN
# 136  585  1913    3.0  14.0          1407.0             2973.0
# 137  589  1966    8.0  12.0             NaN                NaN
# 139  599  1673    5.0  20.0           312.0                NaN
# 140  607  1608    7.0  18.0           222.0                NaN
# 141  617  1772    5.0   9.0           504.0                NaN
# 142  618  1773    2.0   2.0             NaN                NaN
# 144  627  1838    2.0  26.0             NaN                NaN
# 145  629  1840    2.0   2.0           718.0                NaN
# 146  643  1871    8.0   7.0             NaN                NaN
# 147  657  1962   12.0  31.0             NaN                NaN
# 149  664  1646    7.0  19.0          5754.0            10519.0
# 151  666  1861   12.0  29.0             NaN                NaN
# 152  669  1890    6.0  29.0             NaN                NaN
# 153  677  1873    1.0  16.0             NaN                NaN
# 154  679  1871    4.0  30.0          1020.0             2179.0
# 155  680  1950    9.0  15.0             NaN                NaN
# 156  693  1996    8.0  10.0             NaN                NaN
# 157  697  1933   12.0  25.0          1666.0                NaN
# 158  698  1978    7.0  29.0             NaN                NaN
# 159  704  1766    7.0  20.0             NaN                NaN
# 160  706  1800   10.0  30.0             NaN                NaN
# 161  707  1814    2.0   1.0             NaN                NaN
# 162  712  1853    7.0  13.0             NaN                NaN
# 164  716  1871   12.0   8.0             NaN                NaN
# 165  724  1887    3.0   9.0             NaN                NaN
# 166  730  1897    5.0  23.0             NaN                NaN
# 168  733  1938    6.0   5.0             NaN                NaN
# 169  735  1947    1.0   7.0             NaN                NaN
# 170  736  1968    4.0  21.0             NaN                NaN
# 171  739  1984    9.0   9.0             NaN                NaN
# 173  752  1716    9.0  24.0           387.0             1205.0
# 174  753  1749    8.0  11.0           431.0             1304.0
# 175  754  1754   11.0  28.0          2853.0             1328.0
# 176  756  1874    7.0  19.0             NaN                NaN
# 177  761  1911    1.0  30.0          1392.0             8391.0
# 178  762  1965    9.0  28.0          1977.0                NaN
# 179  777  1969    3.0  21.0          2872.0                NaN
# 180  787  1853   10.0  29.0           809.0                NaN
# 182  823  1933   12.0  24.0             NaN                NaN
# 184  844   766    7.0  20.0            61.0             7341.0
# 185  846  1471   11.0   3.0             NaN                NaN
# 186  858  1779   11.0   8.0             NaN                NaN
# 187  859  1781    4.0  11.0           529.0                NaN
# 188  867  1914    1.0  12.0          1412.0             2994.0
# 190  878  1955   10.0  13.0             NaN                NaN
# 191  904  1566   10.0  31.0             NaN                NaN
# 192  915  1716   11.0   9.0             NaN                NaN
# 193  916  1717    2.0   7.0             NaN                NaN
# 194  932  1792    5.0  21.0           568.0             1515.0
# 195  933  1991    6.0   3.0             NaN                NaN
#
#      volcanoLocationId  volcanoLocationNewNum                    name  \
# 0                10106                 211060                    Etna
# 1                10106                 211060                    Etna
# 3                50107                 251070           Ritter Island
# 5                10106                 211060                    Etna
# 6                20303                 223030              Nyiragongo
# 8                10102                 211020                Vesuvius
# 10              201112                 221112                  Alayta
# 11               10102                 211020                Vesuvius
# 12               10104                 211040               Stromboli
# 13               10106                 211060                    Etna
# 14               30301                 233010                Karthala
# 15               50214                 252140                  Rabaul
# 16               10102                 211020                Vesuvius
# 17               40105                 241050                Okataina
# 19               50103                 251030                  Karkar
# 20               10101                 211010           Campi Flegrei
# 22               10102                 211020                Vesuvius
# 23               10102                 211020                Vesuvius
# 24               10104                 211040               Stromboli
# 25               10104                 211040               Stromboli
# 26               40105                 241050                Okataina
# 27               10106                 211060                    Etna
# 28               10102                 211020                Vesuvius
# 29               10106                 211060                    Etna
# 30               10106                 211060                    Etna
# 31               40104                 241040   Whakaari/White Island
# 32               40311                 243110               Niuafo'ou
# 33               20302                 223020             Nyamulagira
# 34               50103                 251030                  Karkar
# 35               10101                 211010           Campi Flegrei
# 36               40311                 243110               Niuafo'ou
# 37               50101                 251010                     Bam
# 38               10102                 211020                Vesuvius
# 39               20403                 224030      Oku Volcanic Field
# 41               10204                 212040               Santorini
# 42              201141                 221141                Dama Ali
# 43               10106                 211060                    Etna
# 44               60320                 263200  Dieng Volcanic Complex
# 45               60320                 263200  Dieng Volcanic Complex
# 47               60325                 263250                  Merapi
# 48               60325                 263250                  Merapi
# 49               60325                 263250                  Merapi
# 50               60325                 263250                  Merapi
# 51               60325                 263250                  Merapi
# 53               60325                 263250                  Merapi
# 54               60325                 263250                  Merapi
# 55               60325                 263250                  Merapi
# 56               60325                 263250                  Merapi
# 57               60325                 263250                  Merapi
# 58               60325                 263250                  Merapi
# 59               60325                 263250                  Merapi
# 65               60328                 263280                   Kelud
# 66               60328                 263280                   Kelud
# 67               60328                 263280                   Kelud
# 68               60328                 263280                   Kelud
# 69               60328                 263280                   Kelud
# 70               60328                 263280                   Kelud
# 71               60328                 263280                   Kelud
# 72               60328                 263280                   Kelud
# 73               60328                 263280                   Kelud
# 74               60328                 263280                   Kelud
# 76               60330                 263300                  Semeru
# 77               60330                 263300                  Semeru
# 78               60330                 263300                  Semeru
# 79               60330                 263300                  Semeru
# 80               60330                 263300                  Semeru
# 81               60330                 263300                  Semeru
# 83               60330                 263300                  Semeru
# 84               60330                 263300                  Semeru
# 85               60330                 263300                  Semeru
# 86               60330                 263300                  Semeru
# 87               60330                 263300                  Semeru
# 88               60330                 263300                  Semeru
# 89               60330                 263300                  Semeru
# 90               60330                 263300                  Semeru
# 98               60335                 263350                    Ijen
# 99               60401                 264010                   Batur
# 100              60402                 264020                   Agung
# 101              60402                 264020                   Agung
# 102              60404                 264040                 Tambora
# 103              60411                 264110                     Iya
# 104              60415                 264150                 Paluweh
# 105              60415                 264150                 Paluweh
# 107              60415                 264150                 Paluweh
# 108              60418                 264180                Lewotobi
# 109              60418                 264180                Lewotobi
# 111              60425                 264250               Iliwerung
# 113              60425                 264250               Iliwerung
# 115              60505                 265050                    Teon
# 117              60507                 265070                   Serua
# 120              60509                 265090               Banda Api
# 121              60509                 265090               Banda Api
# 122              60509                 265090               Banda Api
# 123              60601                 266010                    Colo
# 124              60603                 266030                 Soputan
# 125              60611                 266110                  Mahawu
# 127              60701                 267010                   Ruang
# 128              60702                 267020             Karangetang
# 129              60702                 267020             Karangetang
# 130              60702                 267020             Karangetang
# 131              60703                 267030              Banua Wuhu
# 132              60704                 267040                     Awu
# 133              60704                 267040                     Awu
# 134              60704                 267040                     Awu
# 135              60704                 267040                     Awu
# 136              60704                 267040                     Awu
# 137              60704                 267040                     Awu
# 139              60804                 268040               Gamkonora
# 140              60806                 268060                Gamalama
# 141              60806                 268060                Gamalama
# 142              60806                 268060                Gamalama
# 144              60806                 268060                Gamalama
# 145              60806                 268060                Gamalama
# 146              60806                 268060                Gamalama
# 147              60806                 268060                Gamalama
# 149              60807                 268070                Kie Besi
# 151              60807                 268070                Kie Besi
# 152              60807                 268070                Kie Besi
# 153              70106                 271060                  Ragang
# 154              70108                 271080                Camiguin
# 155              70108                 271080                Camiguin
# 156              70202                 272020                 Kanlaon
# 157              70301                 273010                 Bulusan
# 158              70301                 273010                 Bulusan
# 159              70303                 273030                   Mayon
# 160              70303                 273030                   Mayon
# 161              70303                 273030                   Mayon
# 162              70303                 273030                   Mayon
# 164              70303                 273030                   Mayon
# 165              70303                 273030                   Mayon
# 166              70303                 273030                   Mayon
# 168              70303                 273030                   Mayon
# 169              70303                 273030                   Mayon
# 170              70303                 273030                   Mayon
# 171              70303                 273030                   Mayon
# 173              70307                 273070                    Taal
# 174              70307                 273070                    Taal
# 175              70307                 273070                    Taal
# 176              70307                 273070                    Taal
# 177              70307                 273070                    Taal
# 178              70307                 273070                    Taal
# 179              70402                 274020                 Didicas
# 180              80103                 281030                 Unnamed
# 182              80205                 282050        Kuchinoerabujima
# 184              80208                 282080                    Aira
# 185              80208                 282080                    Aira
# 186              80208                 282080                    Aira
# 187              80208                 282080                    Aira
# 188              80208                 282080                    Aira
# 190              80208                 282080                    Aira
# 191              80209                 282090           Kirishimayama
# 192              80209                 282090           Kirishimayama
# 193              80209                 282090           Kirishimayama
# 194              80210                 282100               Unzendake
# 195              80210                 282100               Unzendake
#
#               country  elevation          morphology  deathsTotal  vei  \
# 0               Italy       3357       Stratovolcano      16000.0  NaN
# 1               Italy       3357       Stratovolcano          NaN  3.0
# 3    Papua New Guinea         75       Stratovolcano          NaN  2.0
# 5               Italy       3357       Stratovolcano          NaN  2.0
# 6          Congo, DRC       3470       Stratovolcano          NaN  1.0
# 8               Italy       1281     Complex volcano          NaN  3.0
# 10           Ethiopia       1496      Shield volcano          NaN  2.0
# 11              Italy       1281     Complex volcano          1.0  2.0
# 12              Italy        924       Stratovolcano          1.0  2.0
# 13              Italy       3357       Stratovolcano          1.0  3.0
# 14            Comoros       2361      Shield volcano          1.0  2.0
# 15   Papua New Guinea        688  Pyroclastic shield          1.0  3.0
# 16              Italy       1281     Complex volcano          2.0  3.0
# 17        New Zealand       1111           Lava dome          2.0  1.0
# 19   Papua New Guinea       1839       Stratovolcano          2.0  2.0
# 20              Italy        458             Caldera          3.0  NaN
# 22              Italy       1281     Complex volcano          4.0  3.0
# 23              Italy       1281     Complex volcano          4.0  2.0
# 24              Italy        924       Stratovolcano          4.0  3.0
# 25              Italy        924       Stratovolcano          6.0  3.0
# 26        New Zealand       1111           Lava dome          4.0  1.0
# 27              Italy       3357       Stratovolcano          5.0  1.0
# 28              Italy       1281     Complex volcano          9.0  3.0
# 29              Italy       3357       Stratovolcano          9.0  3.0
# 30              Italy       3357       Stratovolcano          2.0  2.0
# 31        New Zealand        294       Stratovolcano         11.0  NaN
# 32              Tonga        260      Shield volcano          NaN  4.0
# 33         Congo, DRC       3058      Shield volcano         20.0  3.0
# 34   Papua New Guinea       1839       Stratovolcano         21.0  2.0
# 35              Italy        458             Caldera         24.0  3.0
# 36              Tonga        260      Shield volcano         25.0  0.0
# 37   Papua New Guinea        685       Stratovolcano         25.0  2.0
# 38              Italy       1281     Complex volcano         27.0  3.0
# 39           Cameroon       3011                Maar         37.0  NaN
# 41             Greece        367      Shield volcano         48.0  2.0
# 42           Ethiopia       1068      Shield volcano         50.0  NaN
# 43              Italy       3357       Stratovolcano         59.0  2.0
# 44          Indonesia       2565     Complex volcano        117.0  2.0
# 45          Indonesia       2565     Complex volcano        149.0  1.0
# 47          Indonesia       2910       Stratovolcano       3000.0  3.0
# 48          Indonesia       2910       Stratovolcano        100.0  3.0
# 49          Indonesia       2910       Stratovolcano         32.0  2.0
# 50          Indonesia       2910       Stratovolcano         30.0  4.0
# 51          Indonesia       2910       Stratovolcano        200.0  4.0
# 53          Indonesia       2910       Stratovolcano         35.0  2.0
# 54          Indonesia       2910       Stratovolcano       1369.0  3.0
# 55          Indonesia       2910       Stratovolcano         64.0  2.0
# 56          Indonesia       2910       Stratovolcano          6.0  3.0
# 57          Indonesia       2910       Stratovolcano          3.0  2.0
# 58          Indonesia       2910       Stratovolcano          1.0  2.0
# 59          Indonesia       2910       Stratovolcano         66.0  3.0
# 65          Indonesia       1730       Stratovolcano          NaN  2.0
# 66          Indonesia       1730       Stratovolcano          NaN  4.0
# 67          Indonesia       1730       Stratovolcano         22.0  3.0
# 68          Indonesia       1730       Stratovolcano         54.0  2.0
# 69          Indonesia       1730       Stratovolcano          NaN  NaN
# 70          Indonesia       1730       Stratovolcano          NaN  3.0
# 71          Indonesia       1730       Stratovolcano       5110.0  4.0
# 72          Indonesia       1730       Stratovolcano          7.0  4.0
# 73          Indonesia       1730       Stratovolcano        215.0  4.0
# 74          Indonesia       1730       Stratovolcano         35.0  4.0
# 76          Indonesia       3657       Stratovolcano         74.0  2.0
# 77          Indonesia       3657       Stratovolcano         80.0  2.0
# 78          Indonesia       3657       Stratovolcano        221.0  2.0
# 79          Indonesia       3657       Stratovolcano          NaN  3.0
# 80          Indonesia       3657       Stratovolcano          NaN  2.0
# 81          Indonesia       3657       Stratovolcano          NaN  2.0
# 83          Indonesia       3657       Stratovolcano          NaN  2.0
# 84          Indonesia       3657       Stratovolcano          6.0  1.0
# 85          Indonesia       3657       Stratovolcano          1.0  2.0
# 86          Indonesia       3657       Stratovolcano          3.0  3.0
# 87          Indonesia       3657       Stratovolcano         70.0  3.0
# 88          Indonesia       3657       Stratovolcano         12.0  3.0
# 89          Indonesia       3657       Stratovolcano        119.0  2.0
# 90          Indonesia       3657       Stratovolcano          1.0  3.0
# 98          Indonesia       2769       Stratovolcano          NaN  2.0
# 99          Indonesia       1711             Caldera          2.0  2.0
# 100         Indonesia       2997       Stratovolcano       1028.0  5.0
# 101         Indonesia       2997       Stratovolcano        120.0  3.0
# 102         Indonesia       2850       Stratovolcano      60000.0  7.0
# 103         Indonesia        618       Stratovolcano          2.0  3.0
# 104         Indonesia        875       Stratovolcano        226.0  3.0
# 105         Indonesia        875       Stratovolcano          1.0  2.0
# 107         Indonesia        875       Stratovolcano          NaN  2.0
# 108         Indonesia       1703       Stratovolcano          2.0  2.0
# 109         Indonesia       1703       Stratovolcano          1.0  2.0
# 111         Indonesia        583     Complex volcano          NaN  2.0
# 113         Indonesia        583     Complex volcano          NaN  1.0
# 115     Pacific Ocean        728       Stratovolcano          NaN  4.0
# 117     Pacific Ocean        608       Stratovolcano          NaN  4.0
# 120     Pacific Ocean        596             Caldera          NaN  3.0
# 121     Pacific Ocean        596             Caldera          NaN  2.0
# 122     Pacific Ocean        596             Caldera          4.0  3.0
# 123         Indonesia        404       Stratovolcano          NaN  4.0
# 124         Indonesia       1785       Stratovolcano        118.0  2.0
# 125         Indonesia       1299       Stratovolcano          1.0  2.0
# 127         Indonesia        725       Stratovolcano        400.0  2.0
# 128         Indonesia       1797       Stratovolcano          1.0  2.0
# 129         Indonesia       1797       Stratovolcano          4.0  3.0
# 130         Indonesia       1797       Stratovolcano          1.0  2.0
# 131         Indonesia         -5   Submarine volcano          NaN  2.0
# 132         Indonesia       1318       Stratovolcano       3000.0  3.0
# 133         Indonesia       1318       Stratovolcano        953.0  3.0
# 134         Indonesia       1318       Stratovolcano       2806.0  3.0
# 135         Indonesia       1318       Stratovolcano       1532.0  3.0
# 136         Indonesia       1318       Stratovolcano        138.0  2.0
# 137         Indonesia       1318       Stratovolcano         39.0  4.0
# 139         Indonesia       1635       Stratovolcano          NaN  5.0
# 140         Indonesia       1714       Stratovolcano          NaN  3.0
# 141         Indonesia       1714       Stratovolcano         35.0  3.0
# 142         Indonesia       1714       Stratovolcano          NaN  2.0
# 144         Indonesia       1714       Stratovolcano          4.0  2.0
# 145         Indonesia       1714       Stratovolcano          NaN  3.0
# 146         Indonesia       1714       Stratovolcano          1.0  2.0
# 147         Indonesia       1714       Stratovolcano          5.0  2.0
# 149         Indonesia       1357       Stratovolcano          NaN  4.0
# 151         Indonesia       1357       Stratovolcano        326.0  4.0
# 152         Indonesia       1357       Stratovolcano          NaN  2.0
# 153       Philippines       2790       Stratovolcano          NaN  2.0
# 154       Philippines       1552       Stratovolcano          NaN  2.0
# 155       Philippines       1552       Stratovolcano         68.0  3.0
# 156       Philippines       2422       Stratovolcano          3.0  2.0
# 157       Philippines       1535       Stratovolcano          9.0  2.0
# 158       Philippines       1535       Stratovolcano          NaN  2.0
# 159       Philippines       2462       Stratovolcano         49.0  3.0
# 160       Philippines       2462       Stratovolcano          NaN  2.0
# 161       Philippines       2462       Stratovolcano       1200.0  4.0
# 162       Philippines       2462       Stratovolcano         34.0  3.0
# 164       Philippines       2462       Stratovolcano          3.0  3.0
# 165       Philippines       2462       Stratovolcano         15.0  3.0
# 166       Philippines       2462       Stratovolcano        350.0  3.0
# 168       Philippines       2462       Stratovolcano          NaN  2.0
# 169       Philippines       2462       Stratovolcano          NaN  2.0
# 170       Philippines       2462       Stratovolcano          6.0  3.0
# 171       Philippines       2462       Stratovolcano          1.0  3.0
# 173       Philippines        311       Stratovolcano          NaN  4.0
# 174       Philippines        311       Stratovolcano          NaN  3.0
# 175       Philippines        311       Stratovolcano         12.0  4.0
# 176       Philippines        311       Stratovolcano          NaN  2.0
# 177       Philippines        311       Stratovolcano       1335.0  3.0
# 178       Philippines        311       Stratovolcano        355.0  4.0
# 179       Philippines        228    Compound volcano          3.0  2.0
# 180            Taiwan          0   Submarine volcano          NaN  2.0
# 182             Japan        657       Stratovolcano          8.0  4.0
# 184             Japan       1117       Stratovolcano          NaN  3.0
# 185             Japan       1117       Stratovolcano          NaN  5.0
# 186             Japan       1117       Stratovolcano        153.0  4.0
# 187             Japan       1117       Stratovolcano         38.0  4.0
# 188             Japan       1117       Stratovolcano         63.0  4.0
# 190             Japan       1117       Stratovolcano          NaN  3.0
# 191             Japan       1700      Shield volcano          NaN  3.0
# 192             Japan       1700      Shield volcano          1.0  3.0
# 193             Japan       1700      Shield volcano          1.0  3.0
# 194             Japan       1483     Complex volcano      15000.0  2.0
# 195             Japan       1483     Complex volcano         43.0  1.0
#
#       deaths
# 0        NaN
# 1        NaN
# 3        NaN
# 5        NaN
# 6        NaN
# 8        NaN
# 10       NaN
# 11       1.0
# 12       1.0
# 13       1.0
# 14       1.0
# 15       1.0
# 16       2.0
# 17       2.0
# 19       2.0
# 20       3.0
# 22       4.0
# 23       4.0
# 24       4.0
# 25       5.0
# 26       4.0
# 27       5.0
# 28       9.0
# 29       9.0
# 30       2.0
# 31      11.0
# 32       NaN
# 33      20.0
# 34       1.0
# 35      24.0
# 36      25.0
# 37       NaN
# 38      27.0
# 39      37.0
# 41      48.0
# 42      50.0
# 43      59.0
# 44     117.0
# 45     149.0
# 47    3000.0
# 48     100.0
# 49      32.0
# 50      30.0
# 51     200.0
# 53      35.0
# 54    1369.0
# 55      64.0
# 56       6.0
# 57       3.0
# 58       1.0
# 59      66.0
# 65       NaN
# 66       NaN
# 67      22.0
# 68      54.0
# 69       NaN
# 70       NaN
# 71    5110.0
# 72       7.0
# 73     215.0
# 74      35.0
# 76      74.0
# 77      80.0
# 78     221.0
# 79       NaN
# 80       NaN
# 81       NaN
# 83       NaN
# 84       6.0
# 85       1.0
# 86       3.0
# 87      70.0
# 88      12.0
# 89     119.0
# 90       1.0
# 98       NaN
# 99       2.0
# 100   1028.0
# 101    120.0
# 102  11000.0
# 103      2.0
# 104     98.0
# 105      1.0
# 107      NaN
# 108      2.0
# 109      1.0
# 111      NaN
# 113      NaN
# 115      NaN
# 117      NaN
# 120      NaN
# 121      NaN
# 122      4.0
# 123      NaN
# 124      NaN
# 125      1.0
# 127      NaN
# 128      1.0
# 129      4.0
# 130      1.0
# 131      NaN
# 132   3000.0
# 133    953.0
# 134   2806.0
# 135   1532.0
# 136      NaN
# 137     39.0
# 139      NaN
# 140      NaN
# 141     35.0
# 142      NaN
# 144      4.0
# 145      NaN
# 146      1.0
# 147      5.0
# 149      NaN
# 151    326.0
# 152      NaN
# 153      NaN
# 154      NaN
# 155     68.0
# 156      3.0
# 157      NaN
# 158      NaN
# 159     49.0
# 160      NaN
# 161   1200.0
# 162     34.0
# 164      3.0
# 165     15.0
# 166    350.0
# 168      NaN
# 169      NaN
# 170      6.0
# 171      1.0
# 173      NaN
# 174      NaN
# 175      NaN
# 176      NaN
# 177   1335.0
# 178    355.0
# 179      NaN
# 180      NaN
# 182      8.0
# 184      NaN
# 185      NaN
# 186    153.0
# 187     23.0
# 188     28.0
# 190      NaN
# 191      NaN
# 192      1.0
# 193      1.0
# 194      NaN
# 195     43.0

# %% [markdown]
# **1.2.2:** *In one line of code, **change** the **index column** of the dataframe so that it has **1-based indexing**.*

# %%
new_df.index = range(1, len(df) + 1)

# %% [markdown]
# The **deathsTotal** and **deaths**  columns have approximations of the same data with alternating NaNs in each.
#
# **1.2.3:** *In one line of code, make a **new column** called **'totalDeaths'** that takes the **max** of the values given between those* ***two*** *columns.
# - If there is **NaN** in ***one column*** and a **numerical** value in the **other**, it will ***take the numerical value***.
# - **Only** if there are **NaNs** in ***both columns***, the **new column will have NaN.**

# %%
new_df = new_df.copy()
new_df["totalDeaths"] = new_df[["deathsTotal" , "deaths"]].max(axis=1, skipna=True)

# %% [markdown]
# #### **TASK 1.3: Tailoring Time (10 Points)**
# It's pretty obvious that the year, month, and day look pretty weird in the dataset. We're going to have to do some hardcore cleaning on the [time](https://pandas.pydata.org/docs/user_guide/timeseries.html).
#
# **We need to have only ONE column called** "***date***" **that contains the full date (YYYY-MM-DD), not separated into three columns.**
#
# ***Make sure there are no floating point values in the date and sort the data from most recent to least.***
#
# ***Remove the old columns and place the new column next to the 'id' column.***
#
#
# **YOU CAN USE MULTIPLE LINES OF CODE BUT CAN'T USE LOOPS.**
#
# **Note:** It is alright to have only a **maximum of 12 NaTs** for some dates that often go further back than the 1600s because the datetime module in Pandas has a limit (unless otherwise guided).

# %%
new_df["date"] = pd.to_datetime(
    new_df["year"].astype("Int64").astype(str) + "-" +
    new_df["month"].astype("Int64").astype(str) + "-" +
    new_df["day"].astype("Int64").astype(str),
    errors="coerce"
)
# Drop original columns and sort.
new_df = new_df.drop(columns=["year", "month", "day"])
new_df = new_df.sort_values(by="date", ascending=False).reset_index(drop=True)

# Place new column next to 'id' column.
date_col = new_df.pop("date")
new_df.insert(1, "date", date_col)

# KEEP THIS. It will display the whole dataframe.
#print(new_df["date"].isna().sum()) this is returning 58 but idk why; apparently datetime has issues with years before the 1680s?

new_df
# Out:
# /var/folders/s6/6wkkjw292p9f2tzrykqt_fsh0000gn/T/ipykernel_67107/1409316121.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_df["date"] = pd.to_datetime(
#       id       date  tsunamiEventId  earthquakeEventId  volcanoLocationId  \
# 0    693 1996-08-10             NaN                NaN              70202
# 1    112 1994-11-22             NaN                NaN              60325
# 2    933 1991-06-03             NaN                NaN              80210
# 3    144 1990-02-10             NaN                NaN              60328
# 4    486 1988-05-09             NaN                NaN              60509
# 5     31 1987-04-17             NaN                NaN              10106
# 6    111 1986-12-31             NaN                NaN              60325
# 7     13 1986-07-24             NaN                NaN              10104
# 8    203 1985-05-10             NaN                NaN              60330
# 9    739 1984-09-09             NaN                NaN              70303
# 10    40 1984-08-15          5807.0                NaN              20403
# 11   447 1983-08-17          4702.0                NaN              60425
# 12   488 1983-07-23             NaN                NaN              60601
# 13   398 1981-09-05             NaN                NaN              60415
# 14   206 1981-03-29             NaN                NaN              60330
# 15    30 1979-09-12             NaN                NaN              10106
# 16    20 1979-03-08             NaN                NaN              50103
# 17    49 1979-02-20             NaN                NaN              60320
# 18   204 1978-09-19             NaN                NaN              60330
# 19   698 1978-07-29             NaN                NaN              70301
# 20     7 1977-01-10             NaN                NaN              20303
# 21   562 1976-09-15             NaN                NaN              60702
# 22   205 1976-08-31             NaN                NaN              60330
# 23   561 1974-02-11             NaN                NaN              60702
# 24    21 1970-03-02             NaN                NaN              10101
# 25   777 1969-03-21          2872.0                NaN              70402
# 26   389 1969-01-28             NaN                NaN              60411
# 27   105 1969-01-07             NaN                NaN              60325
# 28   736 1968-04-21             NaN                NaN              70303
# 29   202 1967-08-31             NaN                NaN              60330
# 30   589 1966-08-12             NaN                NaN              60704
# 31   141 1966-04-26             NaN                NaN              60328
# 32   762 1965-09-28          1977.0                NaN              70307
# 33   395 1964-01-01             NaN                NaN              60415
# 34   345 1963-09-05             NaN                NaN              60401
# 35   353 1963-05-16             NaN             4292.0              60402
# 36   201 1963-05-05             NaN                NaN              60330
# 37   351 1963-03-18          1942.0                NaN              60402
# 38   657 1962-12-31             NaN                NaN              60806
# 39   104 1961-05-08             NaN                NaN              60325
# 40   525 1958-07-12             NaN                NaN              60611
# 41   878 1955-10-13             NaN                NaN              80208
# 42    38 1954-08-03             NaN                NaN              50101
# 43   100 1954-01-18             NaN                NaN              60325
# 44   140 1951-08-31             NaN                NaN              60328
# 45   680 1950-09-15             NaN                NaN              70108
# 46   200 1950-08-28             NaN                NaN              60330
# 47   441 1948-04-07             NaN                NaN              60425
# 48   735 1947-01-07             NaN                NaN              70303
# 49   199 1946-10-29             NaN                NaN              60330
# 50    45 1944-12-04             NaN                NaN              60320
# 51    39 1944-03-27             NaN                NaN              10102
# 52   196 1941-09-21             NaN                NaN              60330
# 53   552 1940-06-20             NaN                NaN              60702
# 54   733 1938-06-05             NaN                NaN              70303
# 55   697 1933-12-25          1666.0                NaN              70301
# 56   823 1933-12-24             NaN                NaN              80205
# 57    94 1930-12-18             NaN                NaN              60325
# 58    26 1930-09-11          4218.0                NaN              10104
# 59    28 1928-11-08             NaN                NaN              10106
# 60   394 1928-08-04          1607.0                NaN              60415
# 61    42 1926-01-23             NaN                NaN              10204
# 62    92 1920-07-25             NaN                NaN              60325
# 63    25 1919-05-22          1476.0                NaN              10104
# 64   138 1919-05-19             NaN                NaN              60328
# 65    18 1917-04-01             NaN                NaN              40105
# 66    32 1914-09-10             NaN                NaN              40104
# 67   867 1914-01-12          1412.0             2994.0              80208
# 68   195 1913-06-23             NaN                NaN              60330
# 69   585 1913-03-14          1407.0             2973.0              60704
# 70    34 1912-12-03             NaN                NaN              20302
# 71   193 1911-11-08             NaN                NaN              60330
# 72   761 1911-01-30          1392.0             8391.0              70307
# 73   191 1909-08-29             NaN                NaN              60330
# 74   411 1907-09-28             NaN                NaN              60418
# 75    11 1907-08-04             NaN                NaN             201112
# 76    12 1905-03-10             NaN                NaN              10102
# 77    15 1904-02-25             NaN                NaN              30301
# 78    27 1903-08-30             NaN                NaN              40105
# 79   137 1901-05-22             NaN                NaN              60328
# 80   730 1897-05-23             NaN                NaN              70303
# 81    35 1895-06-17             NaN                NaN              50103
# 82   176 1895-05-22             NaN                NaN              60330
# 83   584 1892-06-07          1197.0                NaN              60704
# 84   669 1890-06-29             NaN                NaN              60807
# 85   569 1889-09-06          1181.0             6309.0              60703
# 86     4 1888-03-13          1175.0                NaN              50107
# 87   724 1887-03-09             NaN                NaN              70303
# 88    33 1886-08-31             NaN                NaN              40311
# 89   167 1885-04-18             NaN                NaN              60330
# 90    16 1878-02-04          1095.0             6195.0              50214
# 91   136 1875-01-29             NaN                NaN              60328
# 92   756 1874-07-19             NaN                NaN              70307
# 93   677 1873-01-16             NaN                NaN              70106
# 94    82 1872-11-03             NaN                NaN              60325
# 95    29 1872-04-24             NaN                NaN              10102
# 96    81 1872-04-15             NaN                NaN              60325
# 97   716 1871-12-08             NaN                NaN              70303
# 98   643 1871-08-07             NaN                NaN              60806
# 99   679 1871-04-30          1020.0             2179.0              70108
# 100  533 1871-03-03          1022.0                NaN              60701
# 101  410 1869-07-07             NaN                NaN              60418
# 102  135 1864-01-04             NaN                NaN              60328
# 103  666 1861-12-29             NaN                NaN              60807
# 104  581 1856-03-02           859.0             1995.0              60704
# 105  787 1853-10-29           809.0                NaN              80103
# 106  712 1853-07-13             NaN                NaN              70303
# 107   37 1853-06-24             NaN                NaN              40311
# 108  133 1848-05-16             NaN                NaN              60328
# 109  489 1845-02-08           741.0             1865.0              60603
# 110   44 1843-11-25             NaN                NaN              10106
# 111  629 1840-02-02           718.0                NaN              60806
# 112  627 1838-02-26             NaN                NaN              60806
# 113   71 1832-12-25             NaN                NaN              60325
# 114    6 1832-11-01             NaN                NaN              10106
# 115  132 1826-10-13             NaN                NaN              60328
# 116   69 1822-12-27             NaN                NaN              60325
# 117  482 1820-06-11             NaN                NaN              60509
# 118  333 1817-01-24             NaN                NaN              60335
# 119  367 1815-04-10           613.0                NaN              60404
# 120  707 1814-02-01             NaN                NaN              70303
# 121  580 1812-08-06             NaN                NaN              60704
# 122   24 1805-08-11             NaN                NaN              10102
# 123  706 1800-10-30             NaN                NaN              70303
# 124  932 1792-05-21           568.0             1515.0              80210
# 125  859 1781-04-11           529.0                NaN              80208
# 126  858 1779-11-08             NaN                NaN              80208
# 127    9 1779-08-08             NaN                NaN              10102
# 128  618 1773-02-02             NaN                NaN              60806
# 129  617 1772-05-09           504.0                NaN              60806
# 130  704 1766-07-20             NaN                NaN              70303
# 131  754 1754-11-28          2853.0             1328.0              70307
# 132  753 1749-08-11           431.0             1304.0              70307
# 133   17 1737-05-20             NaN                NaN              10102
# 134  916 1717-02-07             NaN                NaN              80209
# 135  915 1716-11-09             NaN                NaN              80209
# 136  752 1716-09-24           387.0             1205.0              70307
# 137  128 1716-07-20             NaN                NaN              60328
# 138  578 1711-12-11             NaN                NaN              60704
# 139  477 1694-11-20             NaN                NaN              60509
# 140  466 1692-06-04             NaN                NaN              60507
# 141   23 1682-08-12             NaN                NaN              10102
# 142    1        NaT          2852.0              421.0              10106
# 143    2        NaT             NaN                NaN              10106
# 144    3        NaT             NaN                NaN              30301
# 145    5        NaT             NaN                NaN              50214
# 146    8        NaT             NaN                NaN              10102
# 147   10        NaT             NaN                NaN              10103
# 148   14        NaT             NaN                NaN              10106
# 149   19        NaT             NaN                NaN              50102
# 150   22        NaT             NaN                NaN              30302
# 151   36        NaT             NaN                NaN              10101
# 152   41        NaT             NaN                NaN              10106
# 153   43        NaT             NaN              920.0             201141
# 154   61        NaT             NaN                NaN              60325
# 155   64        NaT             NaN                NaN              60325
# 156   87        NaT             NaN                NaN              60325
# 157  116        NaT             NaN                NaN              60328
# 158  117        NaT             NaN                NaN              60328
# 159  118        NaT             NaN                NaN              60328
# 160  119        NaT             NaN                NaN              60328
# 161  126        NaT             NaN                NaN              60328
# 162  159        NaT             NaN                NaN              60330
# 163  198        NaT             NaN                NaN              60330
# 164  261        NaT             NaN                NaN              60332
# 165  269        NaT             NaN                NaN              60332
# 166  294        NaT             NaN                NaN              60334
# 167  295        NaT             NaN                NaN              60334
# 168  296        NaT             NaN                NaN              60334
# 169  297        NaT             NaN                NaN              60334
# 170  298        NaT             NaN                NaN              60334
# 171  397        NaT             NaN                NaN              60415
# 172  439        NaT             NaN                NaN              60425
# 173  445        NaT          5761.0                NaN              60425
# 174  450        NaT             NaN                NaN              60427
# 175  457        NaT           285.0                NaN              60505
# 176  458        NaT             NaN                NaN              60505
# 177  472        NaT             NaN                NaN              60509
# 178  474        NaT             NaN                NaN              60509
# 179  530        NaT             NaN                NaN              60701
# 180  594        NaT             NaN                NaN              60801
# 181  599        NaT           312.0                NaN              60804
# 182  607        NaT           222.0                NaN              60806
# 183  619        NaT             NaN                NaN              60806
# 184  663        NaT          5863.0                NaN              60807
# 185  664        NaT          5754.0            10519.0              60807
# 186  665        NaT             NaN                NaN              60807
# 187  714        NaT             NaN                NaN              70303
# 188  732        NaT             NaN                NaN              70303
# 189  745        NaT             NaN                NaN              70307
# 190  821        NaT             NaN                NaN              80205
# 191  843        NaT             NaN                NaN              80208
# 192  844        NaT            61.0             7341.0              80208
# 193  846        NaT             NaN                NaN              80208
# 194  874        NaT             NaN                NaN              80208
# 195  904        NaT             NaN                NaN              80209
# 196  949        NaT             NaN                NaN              80211
# 197  960        NaT             NaN                NaN              80211
# 198  990        NaT             NaN                NaN              80211
# 199  994        NaT             NaN                NaN              80211
#
#      volcanoLocationNewNum                    name           country  \
# 0                   272020                 Kanlaon       Philippines
# 1                   263250                  Merapi         Indonesia
# 2                   282100               Unzendake             Japan
# 3                   263280                   Kelud         Indonesia
# 4                   265090               Banda Api     Pacific Ocean
# 5                   211060                    Etna             Italy
# 6                   263250                  Merapi         Indonesia
# 7                   211040               Stromboli             Italy
# 8                   263300                  Semeru         Indonesia
# 9                   273030                   Mayon       Philippines
# 10                  224030      Oku Volcanic Field          Cameroon
# 11                  264250               Iliwerung         Indonesia
# 12                  266010                    Colo         Indonesia
# 13                  264150                 Paluweh         Indonesia
# 14                  263300                  Semeru         Indonesia
# 15                  211060                    Etna             Italy
# 16                  251030                  Karkar  Papua New Guinea
# 17                  263200  Dieng Volcanic Complex         Indonesia
# 18                  263300                  Semeru         Indonesia
# 19                  273010                 Bulusan       Philippines
# 20                  223030              Nyiragongo        Congo, DRC
# 21                  267020             Karangetang         Indonesia
# 22                  263300                  Semeru         Indonesia
# 23                  267020             Karangetang         Indonesia
# 24                  211010           Campi Flegrei             Italy
# 25                  274020                 Didicas       Philippines
# 26                  264110                     Iya         Indonesia
# 27                  263250                  Merapi         Indonesia
# 28                  273030                   Mayon       Philippines
# 29                  263300                  Semeru         Indonesia
# 30                  267040                     Awu         Indonesia
# 31                  263280                   Kelud         Indonesia
# 32                  273070                    Taal       Philippines
# 33                  264150                 Paluweh         Indonesia
# 34                  264010                   Batur         Indonesia
# 35                  264020                   Agung         Indonesia
# 36                  263300                  Semeru         Indonesia
# 37                  264020                   Agung         Indonesia
# 38                  268060                Gamalama         Indonesia
# 39                  263250                  Merapi         Indonesia
# 40                  266110                  Mahawu         Indonesia
# 41                  282080                    Aira             Japan
# 42                  251010                     Bam  Papua New Guinea
# 43                  263250                  Merapi         Indonesia
# 44                  263280                   Kelud         Indonesia
# 45                  271080                Camiguin       Philippines
# 46                  263300                  Semeru         Indonesia
# 47                  264250               Iliwerung         Indonesia
# 48                  273030                   Mayon       Philippines
# 49                  263300                  Semeru         Indonesia
# 50                  263200  Dieng Volcanic Complex         Indonesia
# 51                  211020                Vesuvius             Italy
# 52                  263300                  Semeru         Indonesia
# 53                  267020             Karangetang         Indonesia
# 54                  273030                   Mayon       Philippines
# 55                  273010                 Bulusan       Philippines
# 56                  282050        Kuchinoerabujima             Japan
# 57                  263250                  Merapi         Indonesia
# 58                  211040               Stromboli             Italy
# 59                  211060                    Etna             Italy
# 60                  264150                 Paluweh         Indonesia
# 61                  212040               Santorini            Greece
# 62                  263250                  Merapi         Indonesia
# 63                  211040               Stromboli             Italy
# 64                  263280                   Kelud         Indonesia
# 65                  241050                Okataina       New Zealand
# 66                  241040   Whakaari/White Island       New Zealand
# 67                  282080                    Aira             Japan
# 68                  263300                  Semeru         Indonesia
# 69                  267040                     Awu         Indonesia
# 70                  223020             Nyamulagira        Congo, DRC
# 71                  263300                  Semeru         Indonesia
# 72                  273070                    Taal       Philippines
# 73                  263300                  Semeru         Indonesia
# 74                  264180                Lewotobi         Indonesia
# 75                  221112                  Alayta          Ethiopia
# 76                  211020                Vesuvius             Italy
# 77                  233010                Karthala           Comoros
# 78                  241050                Okataina       New Zealand
# 79                  263280                   Kelud         Indonesia
# 80                  273030                   Mayon       Philippines
# 81                  251030                  Karkar  Papua New Guinea
# 82                  263300                  Semeru         Indonesia
# 83                  267040                     Awu         Indonesia
# 84                  268070                Kie Besi         Indonesia
# 85                  267030              Banua Wuhu         Indonesia
# 86                  251070           Ritter Island  Papua New Guinea
# 87                  273030                   Mayon       Philippines
# 88                  243110               Niuafo'ou             Tonga
# 89                  263300                  Semeru         Indonesia
# 90                  252140                  Rabaul  Papua New Guinea
# 91                  263280                   Kelud         Indonesia
# 92                  273070                    Taal       Philippines
# 93                  271060                  Ragang       Philippines
# 94                  263250                  Merapi         Indonesia
# 95                  211020                Vesuvius             Italy
# 96                  263250                  Merapi         Indonesia
# 97                  273030                   Mayon       Philippines
# 98                  268060                Gamalama         Indonesia
# 99                  271080                Camiguin       Philippines
# 100                 267010                   Ruang         Indonesia
# 101                 264180                Lewotobi         Indonesia
# 102                 263280                   Kelud         Indonesia
# 103                 268070                Kie Besi         Indonesia
# 104                 267040                     Awu         Indonesia
# 105                 281030                 Unnamed            Taiwan
# 106                 273030                   Mayon       Philippines
# 107                 243110               Niuafo'ou             Tonga
# 108                 263280                   Kelud         Indonesia
# 109                 266030                 Soputan         Indonesia
# 110                 211060                    Etna             Italy
# 111                 268060                Gamalama         Indonesia
# 112                 268060                Gamalama         Indonesia
# 113                 263250                  Merapi         Indonesia
# 114                 211060                    Etna             Italy
# 115                 263280                   Kelud         Indonesia
# 116                 263250                  Merapi         Indonesia
# 117                 265090               Banda Api     Pacific Ocean
# 118                 263350                    Ijen         Indonesia
# 119                 264040                 Tambora         Indonesia
# 120                 273030                   Mayon       Philippines
# 121                 267040                     Awu         Indonesia
# 122                 211020                Vesuvius             Italy
# 123                 273030                   Mayon       Philippines
# 124                 282100               Unzendake             Japan
# 125                 282080                    Aira             Japan
# 126                 282080                    Aira             Japan
# 127                 211020                Vesuvius             Italy
# 128                 268060                Gamalama         Indonesia
# 129                 268060                Gamalama         Indonesia
# 130                 273030                   Mayon       Philippines
# 131                 273070                    Taal       Philippines
# 132                 273070                    Taal       Philippines
# 133                 211020                Vesuvius             Italy
# 134                 282090           Kirishimayama             Japan
# 135                 282090           Kirishimayama             Japan
# 136                 273070                    Taal       Philippines
# 137                 263280                   Kelud         Indonesia
# 138                 267040                     Awu         Indonesia
# 139                 265090               Banda Api     Pacific Ocean
# 140                 265070                   Serua     Pacific Ocean
# 141                 211020                Vesuvius             Italy
# 142                 211060                    Etna             Italy
# 143                 211060                    Etna             Italy
# 144                 233010                Karthala           Comoros
# 145                 252140                  Rabaul  Papua New Guinea
# 146                 211020                Vesuvius             Italy
# 147                 211030                  Ischia             Italy
# 148                 211060                    Etna             Italy
# 149                 251020                   Manam  Papua New Guinea
# 150                 233020  Fournaise, Piton de la           Reunion
# 151                 211010           Campi Flegrei             Italy
# 152                 211060                    Etna             Italy
# 153                 221141                Dama Ali          Ethiopia
# 154                 263250                  Merapi         Indonesia
# 155                 263250                  Merapi         Indonesia
# 156                 263250                  Merapi         Indonesia
# 157                 263280                   Kelud         Indonesia
# 158                 263280                   Kelud         Indonesia
# 159                 263280                   Kelud         Indonesia
# 160                 263280                   Kelud         Indonesia
# 161                 263280                   Kelud         Indonesia
# 162                 263300                  Semeru         Indonesia
# 163                 263300                  Semeru         Indonesia
# 164                 263320                Lamongan         Indonesia
# 165                 263320                Lamongan         Indonesia
# 166                 263340                   Raung         Indonesia
# 167                 263340                   Raung         Indonesia
# 168                 263340                   Raung         Indonesia
# 169                 263340                   Raung         Indonesia
# 170                 263340                   Raung         Indonesia
# 171                 264150                 Paluweh         Indonesia
# 172                 264250               Iliwerung         Indonesia
# 173                 264250               Iliwerung         Indonesia
# 174                 264270                  Sirung         Indonesia
# 175                 265050                    Teon     Pacific Ocean
# 176                 265050                    Teon     Pacific Ocean
# 177                 265090               Banda Api     Pacific Ocean
# 178                 265090               Banda Api     Pacific Ocean
# 179                 267010                   Ruang         Indonesia
# 180                 268010                  Dukono         Indonesia
# 181                 268040               Gamkonora         Indonesia
# 182                 268060                Gamalama         Indonesia
# 183                 268060                Gamalama         Indonesia
# 184                 268070                Kie Besi         Indonesia
# 185                 268070                Kie Besi         Indonesia
# 186                 268070                Kie Besi         Indonesia
# 187                 273030                   Mayon       Philippines
# 188                 273030                   Mayon       Philippines
# 189                 273070                    Taal       Philippines
# 190                 282050        Kuchinoerabujima             Japan
# 191                 282080                    Aira             Japan
# 192                 282080                    Aira             Japan
# 193                 282080                    Aira             Japan
# 194                 282080                    Aira             Japan
# 195                 282090           Kirishimayama             Japan
# 196                 282110                  Asosan             Japan
# 197                 282110                  Asosan             Japan
# 198                 282110                  Asosan             Japan
# 199                 282110                  Asosan             Japan
#
#      elevation          morphology  deathsTotal  vei   deaths  totalDeaths
# 0         2422       Stratovolcano          3.0  2.0      3.0          3.0
# 1         2910       Stratovolcano         66.0  3.0     66.0         66.0
# 2         1483     Complex volcano         43.0  1.0     43.0         43.0
# 3         1730       Stratovolcano         35.0  4.0     35.0         35.0
# 4          596             Caldera          4.0  3.0      4.0          4.0
# 5         3357       Stratovolcano          2.0  2.0      2.0          2.0
# 6         2910       Stratovolcano          1.0  2.0      1.0          1.0
# 7          924       Stratovolcano          1.0  2.0      1.0          1.0
# 8         3657       Stratovolcano         70.0  3.0     70.0         70.0
# 9         2462       Stratovolcano          1.0  3.0      1.0          1.0
# 10        3011                Maar         37.0  NaN     37.0         37.0
# 11         583     Complex volcano          NaN  1.0      NaN          NaN
# 12         404       Stratovolcano          NaN  4.0      NaN          NaN
# 13         875       Stratovolcano          NaN  2.0      NaN          NaN
# 14        3657       Stratovolcano          1.0  3.0      1.0          1.0
# 15        3357       Stratovolcano          9.0  3.0      9.0          9.0
# 16        1839       Stratovolcano          2.0  2.0      2.0          2.0
# 17        2565     Complex volcano        149.0  1.0    149.0        149.0
# 18        3657       Stratovolcano         12.0  3.0     12.0         12.0
# 19        1535       Stratovolcano          NaN  2.0      NaN          NaN
# 20        3470       Stratovolcano          NaN  1.0      NaN          NaN
# 21        1797       Stratovolcano          1.0  2.0      1.0          1.0
# 22        3657       Stratovolcano        119.0  2.0    119.0        119.0
# 23        1797       Stratovolcano          4.0  3.0      4.0          4.0
# 24         458             Caldera          3.0  NaN      3.0          3.0
# 25         228    Compound volcano          3.0  2.0      NaN          3.0
# 26         618       Stratovolcano          2.0  3.0      2.0          2.0
# 27        2910       Stratovolcano          3.0  2.0      3.0          3.0
# 28        2462       Stratovolcano          6.0  3.0      6.0          6.0
# 29        3657       Stratovolcano          3.0  3.0      3.0          3.0
# 30        1318       Stratovolcano         39.0  4.0     39.0         39.0
# 31        1730       Stratovolcano        215.0  4.0    215.0        215.0
# 32         311       Stratovolcano        355.0  4.0    355.0        355.0
# 33         875       Stratovolcano          1.0  2.0      1.0          1.0
# 34        1711             Caldera          2.0  2.0      2.0          2.0
# 35        2997       Stratovolcano        120.0  3.0    120.0        120.0
# 36        3657       Stratovolcano          1.0  2.0      1.0          1.0
# 37        2997       Stratovolcano       1028.0  5.0   1028.0       1028.0
# 38        1714       Stratovolcano          5.0  2.0      5.0          5.0
# 39        2910       Stratovolcano          6.0  3.0      6.0          6.0
# 40        1299       Stratovolcano          1.0  2.0      1.0          1.0
# 41        1117       Stratovolcano          NaN  3.0      NaN          NaN
# 42         685       Stratovolcano         25.0  2.0      NaN         25.0
# 43        2910       Stratovolcano         64.0  2.0     64.0         64.0
# 44        1730       Stratovolcano          7.0  4.0      7.0          7.0
# 45        1552       Stratovolcano         68.0  3.0     68.0         68.0
# 46        3657       Stratovolcano          6.0  1.0      6.0          6.0
# 47         583     Complex volcano          NaN  2.0      NaN          NaN
# 48        2462       Stratovolcano          NaN  2.0      NaN          NaN
# 49        3657       Stratovolcano          NaN  2.0      NaN          NaN
# 50        2565     Complex volcano        117.0  2.0    117.0        117.0
# 51        1281     Complex volcano         27.0  3.0     27.0         27.0
# 52        3657       Stratovolcano          NaN  2.0      NaN          NaN
# 53        1797       Stratovolcano          1.0  2.0      1.0          1.0
# 54        2462       Stratovolcano          NaN  2.0      NaN          NaN
# 55        1535       Stratovolcano          9.0  2.0      NaN          9.0
# 56         657       Stratovolcano          8.0  4.0      8.0          8.0
# 57        2910       Stratovolcano       1369.0  3.0   1369.0       1369.0
# 58         924       Stratovolcano          6.0  3.0      5.0          6.0
# 59        3357       Stratovolcano          5.0  1.0      5.0          5.0
# 60         875       Stratovolcano        226.0  3.0     98.0        226.0
# 61         367      Shield volcano         48.0  2.0     48.0         48.0
# 62        2910       Stratovolcano         35.0  2.0     35.0         35.0
# 63         924       Stratovolcano          4.0  3.0      4.0          4.0
# 64        1730       Stratovolcano       5110.0  4.0   5110.0       5110.0
# 65        1111           Lava dome          2.0  1.0      2.0          2.0
# 66         294       Stratovolcano         11.0  NaN     11.0         11.0
# 67        1117       Stratovolcano         63.0  4.0     28.0         63.0
# 68        3657       Stratovolcano          NaN  2.0      NaN          NaN
# 69        1318       Stratovolcano        138.0  2.0      NaN        138.0
# 70        3058      Shield volcano         20.0  3.0     20.0         20.0
# 71        3657       Stratovolcano          NaN  3.0      NaN          NaN
# 72         311       Stratovolcano       1335.0  3.0   1335.0       1335.0
# 73        3657       Stratovolcano        221.0  2.0    221.0        221.0
# 74        1703       Stratovolcano          1.0  2.0      1.0          1.0
# 75        1496      Shield volcano          NaN  2.0      NaN          NaN
# 76        1281     Complex volcano          1.0  2.0      1.0          1.0
# 77        2361      Shield volcano          1.0  2.0      1.0          1.0
# 78        1111           Lava dome          4.0  1.0      4.0          4.0
# 79        1730       Stratovolcano          NaN  3.0      NaN          NaN
# 80        2462       Stratovolcano        350.0  3.0    350.0        350.0
# 81        1839       Stratovolcano         21.0  2.0      1.0         21.0
# 82        3657       Stratovolcano         80.0  2.0     80.0         80.0
# 83        1318       Stratovolcano       1532.0  3.0   1532.0       1532.0
# 84        1357       Stratovolcano          NaN  2.0      NaN          NaN
# 85          -5   Submarine volcano          NaN  2.0      NaN          NaN
# 86          75       Stratovolcano          NaN  2.0      NaN          NaN
# 87        2462       Stratovolcano         15.0  3.0     15.0         15.0
# 88         260      Shield volcano          NaN  4.0      NaN          NaN
# 89        3657       Stratovolcano         74.0  2.0     74.0         74.0
# 90         688  Pyroclastic shield          1.0  3.0      1.0          1.0
# 91        1730       Stratovolcano          NaN  NaN      NaN          NaN
# 92         311       Stratovolcano          NaN  2.0      NaN          NaN
# 93        2790       Stratovolcano          NaN  2.0      NaN          NaN
# 94        2910       Stratovolcano        200.0  4.0    200.0        200.0
# 95        1281     Complex volcano          9.0  3.0      9.0          9.0
# 96        2910       Stratovolcano         30.0  4.0     30.0         30.0
# 97        2462       Stratovolcano          3.0  3.0      3.0          3.0
# 98        1714       Stratovolcano          1.0  2.0      1.0          1.0
# 99        1552       Stratovolcano          NaN  2.0      NaN          NaN
# 100        725       Stratovolcano        400.0  2.0      NaN        400.0
# 101       1703       Stratovolcano          2.0  2.0      2.0          2.0
# 102       1730       Stratovolcano         54.0  2.0     54.0         54.0
# 103       1357       Stratovolcano        326.0  4.0    326.0        326.0
# 104       1318       Stratovolcano       2806.0  3.0   2806.0       2806.0
# 105          0   Submarine volcano          NaN  2.0      NaN          NaN
# 106       2462       Stratovolcano         34.0  3.0     34.0         34.0
# 107        260      Shield volcano         25.0  0.0     25.0         25.0
# 108       1730       Stratovolcano         22.0  3.0     22.0         22.0
# 109       1785       Stratovolcano        118.0  2.0      NaN        118.0
# 110       3357       Stratovolcano         59.0  2.0     59.0         59.0
# 111       1714       Stratovolcano          NaN  3.0      NaN          NaN
# 112       1714       Stratovolcano          4.0  2.0      4.0          4.0
# 113       2910       Stratovolcano         32.0  2.0     32.0         32.0
# 114       3357       Stratovolcano          NaN  2.0      NaN          NaN
# 115       1730       Stratovolcano          NaN  4.0      NaN          NaN
# 116       2910       Stratovolcano        100.0  3.0    100.0        100.0
# 117        596             Caldera          NaN  2.0      NaN          NaN
# 118       2769       Stratovolcano          NaN  2.0      NaN          NaN
# 119       2850       Stratovolcano      60000.0  7.0  11000.0      60000.0
# 120       2462       Stratovolcano       1200.0  4.0   1200.0       1200.0
# 121       1318       Stratovolcano        953.0  3.0    953.0        953.0
# 122       1281     Complex volcano          4.0  2.0      4.0          4.0
# 123       2462       Stratovolcano          NaN  2.0      NaN          NaN
# 124       1483     Complex volcano      15000.0  2.0      NaN      15000.0
# 125       1117       Stratovolcano         38.0  4.0     23.0         38.0
# 126       1117       Stratovolcano        153.0  4.0    153.0        153.0
# 127       1281     Complex volcano          NaN  3.0      NaN          NaN
# 128       1714       Stratovolcano          NaN  2.0      NaN          NaN
# 129       1714       Stratovolcano         35.0  3.0     35.0         35.0
# 130       2462       Stratovolcano         49.0  3.0     49.0         49.0
# 131        311       Stratovolcano         12.0  4.0      NaN         12.0
# 132        311       Stratovolcano          NaN  3.0      NaN          NaN
# 133       1281     Complex volcano          2.0  3.0      2.0          2.0
# 134       1700      Shield volcano          1.0  3.0      1.0          1.0
# 135       1700      Shield volcano          1.0  3.0      1.0          1.0
# 136        311       Stratovolcano          NaN  4.0      NaN          NaN
# 137       1730       Stratovolcano          NaN  2.0      NaN          NaN
# 138       1318       Stratovolcano       3000.0  3.0   3000.0       3000.0
# 139        596             Caldera          NaN  3.0      NaN          NaN
# 140        608       Stratovolcano          NaN  4.0      NaN          NaN
# 141       1281     Complex volcano          4.0  3.0      4.0          4.0
# 142       3357       Stratovolcano      16000.0  NaN      NaN      16000.0
# 143       3357       Stratovolcano          NaN  3.0      NaN          NaN
# 144       2361      Shield volcano          NaN  2.0      NaN          NaN
# 145        688  Pyroclastic shield          NaN  2.0      NaN          NaN
# 146       1281     Complex volcano          NaN  3.0      NaN          NaN
# 147        789     Complex volcano          NaN  NaN      NaN          NaN
# 148       3357       Stratovolcano          1.0  3.0      1.0          1.0
# 149       1807       Stratovolcano          2.0  2.0      2.0          2.0
# 150       2632      Shield volcano          3.0  2.0      3.0          3.0
# 151        458             Caldera         24.0  3.0     24.0         24.0
# 152       3357       Stratovolcano         40.0  NaN     40.0         40.0
# 153       1068      Shield volcano         50.0  NaN     50.0         50.0
# 154       2910       Stratovolcano          NaN  4.0      NaN          NaN
# 155       2910       Stratovolcano       3000.0  3.0   3000.0       3000.0
# 156       2910       Stratovolcano         16.0  2.0     16.0         16.0
# 157       1730       Stratovolcano          NaN  3.0      NaN          NaN
# 158       1730       Stratovolcano          NaN  3.0      NaN          NaN
# 159       1730       Stratovolcano          NaN  3.0      NaN          NaN
# 160       1730       Stratovolcano          NaN  3.0      NaN          NaN
# 161       1730       Stratovolcano      10000.0  5.0  10000.0      10000.0
# 162       3657       Stratovolcano          NaN  2.0      NaN          NaN
# 163       3657       Stratovolcano          6.0  2.0      6.0          6.0
# 164       1641       Stratovolcano          4.0  2.0      4.0          4.0
# 165       1641       Stratovolcano          8.0  2.0      8.0          8.0
# 166       3260       Stratovolcano          NaN  5.0      NaN          NaN
# 167       3260       Stratovolcano          NaN  3.0      NaN          NaN
# 168       3260       Stratovolcano       1001.0  4.0   1001.0       1001.0
# 169       3260       Stratovolcano          NaN  3.0      NaN          NaN
# 170       3260       Stratovolcano          NaN  4.0      NaN          NaN
# 171        875       Stratovolcano          NaN  3.0      NaN          NaN
# 172        583     Complex volcano          NaN  3.0      NaN          NaN
# 173        583     Complex volcano          2.0  2.0      NaN          2.0
# 174       1347     Complex volcano          5.0  0.0      5.0          5.0
# 175        728       Stratovolcano          NaN  4.0      NaN          NaN
# 176        728       Stratovolcano          3.0  4.0      3.0          3.0
# 177        596             Caldera          NaN  3.0      NaN          NaN
# 178        596             Caldera          NaN  3.0      NaN          NaN
# 179        725       Stratovolcano          NaN  2.0      NaN          NaN
# 180       1273     Complex volcano          NaN  3.0      NaN          NaN
# 181       1635       Stratovolcano          NaN  5.0      NaN          NaN
# 182       1714       Stratovolcano          NaN  3.0      NaN          NaN
# 183       1714       Stratovolcano       1300.0  3.0   1300.0       1300.0
# 184       1357       Stratovolcano          NaN  3.0      NaN          NaN
# 185       1357       Stratovolcano          NaN  4.0      NaN          NaN
# 186       1357       Stratovolcano       2000.0  4.0   2000.0       2000.0
# 187       2462       Stratovolcano          NaN  2.0      NaN          NaN
# 188       2462       Stratovolcano          NaN  3.0      NaN          NaN
# 189        311       Stratovolcano          NaN  3.0      NaN          NaN
# 190        657       Stratovolcano          NaN  2.0      NaN          NaN
# 191       1117       Stratovolcano         80.0  4.0     80.0         80.0
# 192       1117       Stratovolcano          NaN  3.0      NaN          NaN
# 193       1117       Stratovolcano          NaN  5.0      NaN          NaN
# 194       1117       Stratovolcano          1.0  2.0      1.0          1.0
# 195       1700      Shield volcano          NaN  3.0      NaN          NaN
# 196       1592             Caldera          NaN  2.0      NaN          NaN
# 197       1592             Caldera          1.0  2.0      1.0          1.0
# 198       1592             Caldera          NaN  2.0      NaN          NaN
# 199       1592             Caldera          3.0  2.0      3.0          3.0

# %% [markdown]
# ### **Part 2: Volcanic Matryoshkas 🪆 (30 POINTS TOTAL)**
#
# Now, that most of the data has been tidied up. We will organize the data into more sizable pieces of information in order to extract useful information.

# %% [markdown]
# **2.1.1:** *(10 points here)*
#
# Use the **groupby function in Pandas** to create separate dataframes for each unique country.
#
# * **Each table must only have the columns**: 'date' 'country', 'name', and 'vei' (Having the index is ok. Up to you.)
#
# * **Sort** the dataframe of **each country** by **highest to lowest 'vei'**
#
# * Use the **[display](https://ipython.readthedocs.io/en/8.26.0/api/generated/IPython.display.html)** function to show **each sorted table**
#
# **You MUST use the groupby function here and display your results.**

# %%
from IPython.display import display

subset = new_df[["date", "country", "name", "vei"]]
for country, group in subset.groupby("country"):
    sorted_group = group.sort_values(by="vei", ascending=False)
    display(sorted_group)
# Out:
#          date   country                name  vei
# 10 1984-08-15  Cameroon  Oku Volcanic Field  NaN
#           date  country      name  vei
# 77  1904-02-25  Comoros  Karthala  2.0
# 144        NaT  Comoros  Karthala  2.0
#          date     country         name  vei
# 70 1912-12-03  Congo, DRC  Nyamulagira  3.0
# 20 1977-01-10  Congo, DRC   Nyiragongo  1.0
#           date   country      name  vei
# 75  1907-08-04  Ethiopia    Alayta  2.0
# 153        NaT  Ethiopia  Dama Ali  NaN
#          date country       name  vei
# 61 1926-01-23  Greece  Santorini  2.0
#           date    country                    name  vei
# 119 1815-04-10  Indonesia                 Tambora  7.0
# 37  1963-03-18  Indonesia                   Agung  5.0
# 181        NaT  Indonesia               Gamkonora  5.0
# 166        NaT  Indonesia                   Raung  5.0
# 161        NaT  Indonesia                   Kelud  5.0
# 103 1861-12-29  Indonesia                Kie Besi  4.0
# 44  1951-08-31  Indonesia                   Kelud  4.0
# 64  1919-05-19  Indonesia                   Kelud  4.0
# 94  1872-11-03  Indonesia                  Merapi  4.0
# 3   1990-02-10  Indonesia                   Kelud  4.0
# 96  1872-04-15  Indonesia                  Merapi  4.0
# 115 1826-10-13  Indonesia                   Kelud  4.0
# 31  1966-04-26  Indonesia                   Kelud  4.0
# 168        NaT  Indonesia                   Raung  4.0
# 170        NaT  Indonesia                   Raung  4.0
# 185        NaT  Indonesia                Kie Besi  4.0
# 154        NaT  Indonesia                  Merapi  4.0
# 186        NaT  Indonesia                Kie Besi  4.0
# 30  1966-08-12  Indonesia                     Awu  4.0
# 12  1983-07-23  Indonesia                    Colo  4.0
# 111 1840-02-02  Indonesia                Gamalama  3.0
# 159        NaT  Indonesia                   Kelud  3.0
# 104 1856-03-02  Indonesia                     Awu  3.0
# 108 1848-05-16  Indonesia                   Kelud  3.0
# 116 1822-12-27  Indonesia                  Merapi  3.0
# 18  1978-09-19  Indonesia                  Semeru  3.0
# 121 1812-08-06  Indonesia                     Awu  3.0
# 129 1772-05-09  Indonesia                Gamalama  3.0
# 138 1711-12-11  Indonesia                     Awu  3.0
# 155        NaT  Indonesia                  Merapi  3.0
# 157        NaT  Indonesia                   Kelud  3.0
# 158        NaT  Indonesia                   Kelud  3.0
# 14  1981-03-29  Indonesia                  Semeru  3.0
# 160        NaT  Indonesia                   Kelud  3.0
# 26  1969-01-28  Indonesia                     Iya  3.0
# 167        NaT  Indonesia                   Raung  3.0
# 169        NaT  Indonesia                   Raung  3.0
# 171        NaT  Indonesia                 Paluweh  3.0
# 172        NaT  Indonesia               Iliwerung  3.0
# 180        NaT  Indonesia                  Dukono  3.0
# 8   1985-05-10  Indonesia                  Semeru  3.0
# 182        NaT  Indonesia                Gamalama  3.0
# 183        NaT  Indonesia                Gamalama  3.0
# 184        NaT  Indonesia                Kie Besi  3.0
# 23  1974-02-11  Indonesia             Karangetang  3.0
# 1   1994-11-22  Indonesia                  Merapi  3.0
# 29  1967-08-31  Indonesia                  Semeru  3.0
# 39  1961-05-08  Indonesia                  Merapi  3.0
# 57  1930-12-18  Indonesia                  Merapi  3.0
# 71  1911-11-08  Indonesia                  Semeru  3.0
# 79  1901-05-22  Indonesia                   Kelud  3.0
# 60  1928-08-04  Indonesia                 Paluweh  3.0
# 35  1963-05-16  Indonesia                   Agung  3.0
# 83  1892-06-07  Indonesia                     Awu  3.0
# 38  1962-12-31  Indonesia                Gamalama  2.0
# 165        NaT  Indonesia                Lamongan  2.0
# 6   1986-12-31  Indonesia                  Merapi  2.0
# 53  1940-06-20  Indonesia             Karangetang  2.0
# 52  1941-09-21  Indonesia                  Semeru  2.0
# 50  1944-12-04  Indonesia  Dieng Volcanic Complex  2.0
# 162        NaT  Indonesia                  Semeru  2.0
# 163        NaT  Indonesia                  Semeru  2.0
# 164        NaT  Indonesia                Lamongan  2.0
# 13  1981-09-05  Indonesia                 Paluweh  2.0
# 36  1963-05-05  Indonesia                  Semeru  2.0
# 49  1946-10-29  Indonesia                  Semeru  2.0
# 47  1948-04-07  Indonesia               Iliwerung  2.0
# 85  1889-09-06  Indonesia              Banua Wuhu  2.0
# 43  1954-01-18  Indonesia                  Merapi  2.0
# 173        NaT  Indonesia               Iliwerung  2.0
# 179        NaT  Indonesia                   Ruang  2.0
# 40  1958-07-12  Indonesia                  Mahawu  2.0
# 84  1890-06-29  Indonesia                Kie Besi  2.0
# 156        NaT  Indonesia                  Merapi  2.0
# 62  1920-07-25  Indonesia                  Merapi  2.0
# 34  1963-09-05  Indonesia                   Batur  2.0
# 89  1885-04-18  Indonesia                  Semeru  2.0
# 82  1895-05-22  Indonesia                  Semeru  2.0
# 98  1871-08-07  Indonesia                Gamalama  2.0
# 100 1871-03-03  Indonesia                   Ruang  2.0
# 101 1869-07-07  Indonesia                Lewotobi  2.0
# 102 1864-01-04  Indonesia                   Kelud  2.0
# 22  1976-08-31  Indonesia                  Semeru  2.0
# 74  1907-09-28  Indonesia                Lewotobi  2.0
# 109 1845-02-08  Indonesia                 Soputan  2.0
# 33  1964-01-01  Indonesia                 Paluweh  2.0
# 112 1838-02-26  Indonesia                Gamalama  2.0
# 113 1832-12-25  Indonesia                  Merapi  2.0
# 21  1976-09-15  Indonesia             Karangetang  2.0
# 73  1909-08-29  Indonesia                  Semeru  2.0
# 118 1817-01-24  Indonesia                    Ijen  2.0
# 69  1913-03-14  Indonesia                     Awu  2.0
# 128 1773-02-02  Indonesia                Gamalama  2.0
# 68  1913-06-23  Indonesia                  Semeru  2.0
# 137 1716-07-20  Indonesia                   Kelud  2.0
# 27  1969-01-07  Indonesia                  Merapi  2.0
# 46  1950-08-28  Indonesia                  Semeru  1.0
# 17  1979-02-20  Indonesia  Dieng Volcanic Complex  1.0
# 11  1983-08-17  Indonesia               Iliwerung  1.0
# 174        NaT  Indonesia                  Sirung  0.0
# 91  1875-01-29  Indonesia                   Kelud  NaN
#           date country           name  vei
# 151        NaT   Italy  Campi Flegrei  3.0
# 127 1779-08-08   Italy       Vesuvius  3.0
# 15  1979-09-12   Italy           Etna  3.0
# 51  1944-03-27   Italy       Vesuvius  3.0
# 58  1930-09-11   Italy      Stromboli  3.0
# 148        NaT   Italy           Etna  3.0
# 63  1919-05-22   Italy      Stromboli  3.0
# 146        NaT   Italy       Vesuvius  3.0
# 95  1872-04-24   Italy       Vesuvius  3.0
# 143        NaT   Italy           Etna  3.0
# 141 1682-08-12   Italy       Vesuvius  3.0
# 133 1737-05-20   Italy       Vesuvius  3.0
# 5   1987-04-17   Italy           Etna  2.0
# 122 1805-08-11   Italy       Vesuvius  2.0
# 114 1832-11-01   Italy           Etna  2.0
# 7   1986-07-24   Italy      Stromboli  2.0
# 76  1905-03-10   Italy       Vesuvius  2.0
# 110 1843-11-25   Italy           Etna  2.0
# 59  1928-11-08   Italy           Etna  1.0
# 24  1970-03-02   Italy  Campi Flegrei  NaN
# 142        NaT   Italy           Etna  NaN
# 147        NaT   Italy         Ischia  NaN
# 152        NaT   Italy           Etna  NaN
#           date country              name  vei
# 193        NaT   Japan              Aira  5.0
# 56  1933-12-24   Japan  Kuchinoerabujima  4.0
# 67  1914-01-12   Japan              Aira  4.0
# 125 1781-04-11   Japan              Aira  4.0
# 126 1779-11-08   Japan              Aira  4.0
# 191        NaT   Japan              Aira  4.0
# 134 1717-02-07   Japan     Kirishimayama  3.0
# 135 1716-11-09   Japan     Kirishimayama  3.0
# 41  1955-10-13   Japan              Aira  3.0
# 192        NaT   Japan              Aira  3.0
# 195        NaT   Japan     Kirishimayama  3.0
# 190        NaT   Japan  Kuchinoerabujima  2.0
# 196        NaT   Japan            Asosan  2.0
# 198        NaT   Japan            Asosan  2.0
# 197        NaT   Japan            Asosan  2.0
# 199        NaT   Japan            Asosan  2.0
# 194        NaT   Japan              Aira  2.0
# 124 1792-05-21   Japan         Unzendake  2.0
# 2   1991-06-03   Japan         Unzendake  1.0
#          date      country                   name  vei
# 65 1917-04-01  New Zealand               Okataina  1.0
# 78 1903-08-30  New Zealand               Okataina  1.0
# 66 1914-09-10  New Zealand  Whakaari/White Island  NaN
#           date        country       name  vei
# 140 1692-06-04  Pacific Ocean      Serua  4.0
# 175        NaT  Pacific Ocean       Teon  4.0
# 176        NaT  Pacific Ocean       Teon  4.0
# 4   1988-05-09  Pacific Ocean  Banda Api  3.0
# 139 1694-11-20  Pacific Ocean  Banda Api  3.0
# 177        NaT  Pacific Ocean  Banda Api  3.0
# 178        NaT  Pacific Ocean  Banda Api  3.0
# 117 1820-06-11  Pacific Ocean  Banda Api  2.0
#           date           country           name  vei
# 90  1878-02-04  Papua New Guinea         Rabaul  3.0
# 16  1979-03-08  Papua New Guinea         Karkar  2.0
# 42  1954-08-03  Papua New Guinea            Bam  2.0
# 81  1895-06-17  Papua New Guinea         Karkar  2.0
# 86  1888-03-13  Papua New Guinea  Ritter Island  2.0
# 145        NaT  Papua New Guinea         Rabaul  2.0
# 149        NaT  Papua New Guinea          Manam  2.0
#           date      country      name  vei
# 131 1754-11-28  Philippines      Taal  4.0
# 32  1965-09-28  Philippines      Taal  4.0
# 136 1716-09-24  Philippines      Taal  4.0
# 120 1814-02-01  Philippines     Mayon  4.0
# 72  1911-01-30  Philippines      Taal  3.0
# 97  1871-12-08  Philippines     Mayon  3.0
# 130 1766-07-20  Philippines     Mayon  3.0
# 9   1984-09-09  Philippines     Mayon  3.0
# 87  1887-03-09  Philippines     Mayon  3.0
# 80  1897-05-23  Philippines     Mayon  3.0
# 189        NaT  Philippines      Taal  3.0
# 132 1749-08-11  Philippines      Taal  3.0
# 45  1950-09-15  Philippines  Camiguin  3.0
# 28  1968-04-21  Philippines     Mayon  3.0
# 188        NaT  Philippines     Mayon  3.0
# 106 1853-07-13  Philippines     Mayon  3.0
# 187        NaT  Philippines     Mayon  2.0
# 123 1800-10-30  Philippines     Mayon  2.0
# 0   1996-08-10  Philippines   Kanlaon  2.0
# 99  1871-04-30  Philippines  Camiguin  2.0
# 93  1873-01-16  Philippines    Ragang  2.0
# 55  1933-12-25  Philippines   Bulusan  2.0
# 54  1938-06-05  Philippines     Mayon  2.0
# 48  1947-01-07  Philippines     Mayon  2.0
# 25  1969-03-21  Philippines   Didicas  2.0
# 19  1978-07-29  Philippines   Bulusan  2.0
# 92  1874-07-19  Philippines      Taal  2.0
#     date  country                    name  vei
# 150  NaT  Reunion  Fournaise, Piton de la  2.0
#           date country     name  vei
# 105 1853-10-29  Taiwan  Unnamed  2.0
#           date country       name  vei
# 88  1886-08-31   Tonga  Niuafo'ou  4.0
# 107 1853-06-24   Tonga  Niuafo'ou  0.0

# %% [markdown]
# **2.1.2:** *(5 points here)*
#
# Using **groupby again**, print out the **maximum 'vei'** for **each unique country.**
#
# **You MUST use the groupby function here and print your results.**
#
# * **Print** out your results in a format like the following: "Country: {country_name}, Highest VEI: {vei}"

# %%
max_vei = new_df.groupby("country")["vei"].max()

for country, vei in max_vei.items():
    print(f"Country: {country}, Highest VEI: {vei}")
# Out:
# Country: Cameroon, Highest VEI: nan
# Country: Comoros, Highest VEI: 2.0
# Country: Congo, DRC, Highest VEI: 3.0
# Country: Ethiopia, Highest VEI: 2.0
# Country: Greece, Highest VEI: 2.0
# Country: Indonesia, Highest VEI: 7.0
# Country: Italy, Highest VEI: 3.0
# Country: Japan, Highest VEI: 5.0
# Country: New Zealand, Highest VEI: 1.0
# Country: Pacific Ocean, Highest VEI: 4.0
# Country: Papua New Guinea, Highest VEI: 3.0
# Country: Philippines, Highest VEI: 4.0
# Country: Reunion, Highest VEI: 2.0
# Country: Taiwan, Highest VEI: 2.0
# Country: Tonga, Highest VEI: 4.0

# %% [markdown]
# Finally, we have ALMOST REACHED THE END!!
# Since there is still quite a bit of missing data, we want to make use of what is still available.
#
# A very powerful tool in Python's magnificent collection of libraries is its beautiful graphing tools.
#
# Check out libraries such as [Seaborn](https://seaborn.pydata.org/) or [Matplotlib](https://matplotlib.org/stable/index.html) to create meaningful visualizations! **Your final task in this section requires the use of these libraries**
#
# **2.1.3:** *(15 points here)*
#
# - Based on the **unique names of volcanoes**, **filter names that have more than 4 datapoints under their name.**
# - Each datapoint in the dataframe refers to a recorded instance of a volcanic eruption.
# - Make **separate line graphs for each volcano** and **plot their VEIs over time.**
#
# **Make sure to properly label all parts of the graph appropriately to receive credit 👀** (like title, axes, legend, etc...)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
counts = new_df["name"].value_counts()
volcanoes = counts[counts>4].index.to_list()
filtered = new_df[new_df["name"].isin(volcanoes)]


# not adding the graphs here, but the graphs should have the volcano name as the title
# the x axis should be the years and the y axis should be the VEI
# A graph that doesn't have these things will only get partial points
for volcano, group in filtered.groupby("name"):
    group = group.dropna(subset=["vei", "date"])
    if group.empty:
        continue
    
    plt.figure(figsize=(8,5))
    plt.plot(group["date"], group["vei"], marker="o", linestyle="-", label=volcano)

    plt.title(f"{volcano}")
    plt.xlabel("Date")
    plt.ylabel("VEI")
    plt.legend()
    plt.grid(True)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

    plt.show()

# %% [markdown]
# ### **Part 3: Fiery Jobs 🚒 (15 POINTS TOTAL)**
#
# Proficiency in SQL is also super important. SQL databases are essentially relational databases in which there are vast amounts of tabular data. which can often be used to connect with related tablular data. [This](https://www.w3schools.com/sql/) is a pretty good intro into learning more about SQL.

# %% [markdown]
# Check out this [tutorial](https://mode.com/sql-tutorial/introduction-to-sql/) for some clarifications on SQL.
#
# Now! We'll be using **`sqlite`** to access a database.
# * **!!!IMPORTANT!!! PLEASE Start by downloading the sql lite file and putting it in the same directory as this [KAGGLE DATASET URL](https://www.kaggle.com/datasets/kaggle/sf-salaries) (hit the 'download' button in the upper right). You need an account in order to download the dataset.**
# * Check out the description of the data so you know the table / column names.
#
# The following code will use `sqlite3` to create a database connection. `sqlite3` is the library in Python that assists in navigating through SQL databases.
#
# **Note:** If you are working on this assignment via Google Colab, sometimes the runtime resets and it will throw errors.
#
# ***Instead of running through the entire notebook, run the notebook from the following code block and onwards:***
# - Click anywhere on the next code block.
# - Go up to where it says **'Runtime'** in the toolbar (right under the title of the notebook and **in between 'Insert' and 'Tools'**)
# - Hover over it and **click on the option** that says **'Run cell and below'**

# %%
import sqlite3
import pandas as pd # Pandas was already imported from the previous sections

conn = sqlite3.connect("database.sqlite")
crsr = conn.cursor()

# %% [markdown]
# ## **!!!IMPORTANT!!! PLEASE Start by downloading the sql lite file and putting it in the same directory as this [KAGGLE DATASET URL](https://www.kaggle.com/datasets/kaggle/sf-salaries) (hit the 'download' button in the upper right). You need an account in order to download the dataset.**
#
# ##### If you cannot see anything when executing this code, that means you did not download the Kaggle dataset correctly.

# %%
# This code will let you check out the different tables within the database.
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = crsr.execute(query).fetchall()
print(tables)
# Out:
# [('Salaries',)]

# %% [markdown]
# #### **Remember that each problem should be solved with a single SQL query.**
# **Note: All outputs must be shown**
# - Only include whatever fields are mentioned throughout each question, nothing more and nothing less.
# - Follow each instruction clearly
#
# #### **3.1.1: 2 Points**
# From the **Salaries** table, get the **average base pay** for firefighters (all job titles consisting of the word "firefighter" **(not case-sensitive)**) between the **years 2010 to 2015**.
#
# *Remember that firefighters that also occupy other professions are still considered firefighters.*
#
# *Hint: Look into [this](https://www.w3schools.com/mysql/mysql_wildcards.asp) 👀*

# %%
query = '''
SELECT AVG(BasePay) AS avg_base_pay
FROM Salaries
WHERE LOWER(JobTitle) LIKE '%firefighter%'
  AND Year BETWEEN 2010 AND 2015;
'''

# KEEP THIS. It will display the whole dataframe.
df = pd.read_sql(query, conn)
df
# Out:
#     avg_base_pay
# 0  101199.486996

# %% [markdown]
# #### **3.1.2: 2 Points**
# From the **Salaries** table, get all the firefighters (all job titles consisting of the word "firefighter" **(not case-sensitive)**) in the **year 2011** making under **$40,000 as a base pay.** **Sort** them in **descending** order by their pay.
#
# *Remember that firefighters that also occupy other professions are still considered firefighters.*

# %%
query = '''
SELECT EmployeeName, JobTitle, BasePay
FROM Salaries
WHERE LOWER(JobTitle) LIKE '%firefighter%'
  AND Year = 2011
  AND BasePay < 40000
ORDER BY BasePay DESC;
'''
# KEEP THIS. It will display the whole dataframe.
df = pd.read_sql(query, conn)
df
# Out:
#           EmployeeName     JobTitle   BasePay
# 0   MEIBEK SCOTT-CHUNG  FIREFIGHTER  37495.09
# 1          LAURA ATTIA  FIREFIGHTER  35779.10
# 2        MICHAEL CUDDY  FIREFIGHTER  32058.01
# 3           FELIX DUAG  FIREFIGHTER  20658.44
# 4     DANIEL ARCINIEGA  FIREFIGHTER  13345.28
# 5          GREG BARRON  FIREFIGHTER  13046.35
# 6          JAMES MOORE  FIREFIGHTER   7896.00
# 7    ALLISON KALHAMMER  FIREFIGHTER   7477.60
# 8        DARREN MILLER  FIREFIGHTER   7477.60
# 9      MARTIN GREALISH  FIREFIGHTER   6880.50
# 10      SARAH HAMILTON  FIREFIGHTER   4350.41
# 11      ANGELA FREEMAN  FIREFIGHTER      0.00
# 12       WILLIAM KNEIS  FIREFIGHTER      0.00
# 13    MARK CHERRINGTON  FIREFIGHTER      0.00
# 14         JOHN BENSON  FIREFIGHTER      0.00
# 15      ERIKA LOCKHART  FIREFIGHTER      0.00
# 16     CHARLES JOHNSON  FIREFIGHTER      0.00
# 17       ROBERTO LUCHA  FIREFIGHTER      0.00
# 18       ROCK CRAWFORD  FIREFIGHTER      0.00

# %% [markdown]
# #### **3.1.3: 4 Points**
# From the **Salaries** table, first get the **averages** of **base pay**, **benefits**, and **overtime pay** for firefighters (all job titles consisting of the word "firefighter" **(not case-sensitive)**).
#
# - Then, make a **column with the sum** of these **three averages**
# - Finally, **exclude** job titles containing "FIREFIGHTER" **(case-sensitive)**
#
# *Remember that firefighters that also occupy other professions are still considered firefighters.*

# %%
query = '''
SELECT 
    AVG(BasePay) AS avg_basepay,
    AVG(Benefits) AS avg_benefits,
    AVG(OvertimePay) AS avg_overtime,
    (AVG(BasePay) + AVG(Benefits) + AVG(OvertimePay)) AS total_avg
FROM Salaries
WHERE LOWER(JobTitle) LIKE '%firefighter%'
'''

# KEEP THIS. It will display the whole dataframe.
df = pd.read_sql(query, conn)
df
# Out:
#      avg_basepay  avg_benefits  avg_overtime      total_avg
# 0  101199.486996   29404.01156  25932.604456  156536.103012

# %% [markdown]
# #### **3.1.4: 7 Points**
#
# Finally, we'll make our own table in our database.
#
# * Separate the **Salaries table** by **years (2010-2015)**, and add it back to the database.
# - Using a loop might be helpful.
#
# * You may use basic python to complete the task. However, using querying on SQL is **mandatory**.
# * Feel free to **use multiple lines of code for this problem only.**
#
# *Hint: Check [this](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html) out*

# %%
import pandas as pd

for year in range(2010, 2016):
    query = f"SELECT * FROM SALARIES WHERE Year = {year};"
    df_year = pd.read_sql(query,conn)
    
    table_name = f"Salaries_{year}"
    df_year.to_sql(table_name, conn, if_exists="replace", index=False)

# %%
# Run this code to check if you successfully added your table.
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('Salaries',), ('Salaries_2010',), ('Salaries_2011',), ('Salaries_2012',), ('Salaries_2013',), ('Salaries_2014',), ('Salaries_2015',)]

# %% [markdown]
# ![volcano](https://as1.ftcdn.net/v2/jpg/06/34/76/64/1000_F_634766457_0fZbpYj6aBLlldO1jADUPpKTRLnNmngs.jpg)

# %% [markdown]
# ### **Part 4: Pandas 'Group By'(40 points)**

# %% [markdown]
# This flowchart is taken from our lecture class presentation and illustrates the process of transforming data using the Pandas GroupBy operation. First, the data is input, followed by applying the GroupBy function to one or more columns of the DataFrame. Once the data is grouped, an aggregation function (such as sum(), mean(), or count()) is applied to compute summary statistics for each group
#
#
#
# ![bonus](https://drive.google.com/uc?export=view&id=1OeO3cVJSgmk6QxeBUp5ojJQUGVAPB-Jx)

# %% [markdown]
# Your task is to translate the workflow shown in the flowchart into Pandas queries that perform these operations step by step.
#
# **Notes:** Your task is to translate the workflow shown in the flowchart into Pandas queries. Ensure that the **exact input and exact output** from the flowchart are replicated using Pandas queries, step by step.

# %% [markdown]
# **4.1 (Point 10 )** Create a sample dataset that includes columns for account, order, and ext price.

# %%
# Create the Sample dataset from above flowchart
input_data = {
    'account': ['383080', '383080', '383080', '412290', '412290','412290','412290','412290','218895','218895','218895','218895'],
    'order': ['10001', '10001', '10001', '10005', '10005','10005','10005','10005','10006','10006','10006','10006'],
    'ext_price': [235.83, 232.32, 107.97, 2679.36, 286.02, 832.95, 3472.04, 915.12, 3061.12, 518.65, 216.9, -72.18]
}

# Create DataFrame


# Display Dataframe (DONT REMOVE THE CODE)

# %% [markdown]
# **4.2 (Point 10+10 =20 )** Group by order and show the intermediate results

# %%
# Group by 'order' and show intermediate result


# Display intermediate result for each group; hints: you have to use 'for loop'

# %% [markdown]
# **4.3 (Point 10 )** Apply the Sum Aggregation for Each Group
#
# Now we'll apply the sum aggregation to get the total ext price for each order:

# %%
# Repeat group by 'order' again and then apply aggregation (sum of 'ext_price' for each 'order')


# Show the aggregated result after re-grouping  (DONT REMOVE THE CODE)

# %% [markdown]
# **4.4 (Point 10)**  Combine the Results into One Final Table
# Finally, we will **reset the index** and create a combined table that shows order and the sum of the ext price for each group:
#
#
# **Notes**: In pandas, 'reset_index()' is a method used to reset the index of a DataFrame to its default integer-based index. By default, when you perform certain operations like groupby(), the resulting DataFrame may have a new index (e.g., the grouped column). The reset_index() method allows you to convert the current index back to a default sequential integer index and optionally, move the current index values into a regular column.

# %%
# Reset index to combine result into a single DataFrame

# Rename the columns for clarity


# Show the final result  (DONT REMOVE THE CODE)

# %% [markdown]
# # Bonus(1 point): Assignment Submission with Jupyter Notebook file(ipynb) and PDF

# %% [markdown]
# In addition to the instruction of the special bonus question included exclusively in Assignment 1, we would like to highlight the importance of developing good practices for assignment submission in data science projects.
#
# Think of yourself as a reviewer of your peers’ work: what would you pay attention to if you had to grade their assignments? Clearly, the raw dataset itself is not the main point—why would someone need to see every line of data you downloaded? Data science is about analysis and insight, not just data collection. What truly matters is how you analyze the data and how you present your results.
#
# For a clean and effective submission, please avoid printing entire datasets unless they are directly relevant to the presentation of your output or if you are asked to do so. Instead, focus on:
#
# *   Showing your algorithm with clear, concise code
# *   Displaying the key results you want us to evaluate (or the outputs you relied on while working)
# *   Adding a short explanation when asked to interpret your findings
#
# For this bonus question, please submit both your .ipynb file and the PDF version. To create a PDF: go to File (top left corner in Jupyter Notebook) → Print → Destination → Save as PDF.
#
# Are you noticing an overwhelming amount of unnecessary printed results in your PDF? This is exactly why we emphasize the importance of cleaning up your work before submission. Removing trivial data printing makes your notebook look much more professional and easier to review—just like proofreading an essay for good grammar.
#
# Your Homework 1 submission should be lightweight and focused, since this is a starter project designed to help you ease into the semester. :)
#
# This practice helps us grade more efficiently and ensures fairness, since we can always reference your original notebook if regrading is needed.
